# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
from math import sqrt
from numpy import concatenate
from pandas import read_csv, DataFrame, concat
from datetime import datetime
from sklearn.metrics import mean_squared_error

from sklearn.preprocessing import MinMaxScaler, StandardScaler

import keras.backend as K
from keras.layers import Multiply
from keras.models import Sequential ,Model
from keras.layers import Dense , Input , Reshape , Flatten ,Permute , Lambda , RepeatVector ,Conv1D , MaxPooling1D , Dropout, Bidirectional, Activation
from keras.layers import GRU, LSTM
from keras.utils.vis_utils import plot_model
from keras.optimizers import SGD,Adam
from keras.utils import np_utils   #np_utils
from keras.callbacks import TensorBoard  #TensorBoard可视化
# Out:
# Using TensorFlow backend.

# %%
# T:0
# H:1
# Surge:2
# Heave:4
# Force1:8
# 四级海况（波高2周期11.2水深50)
data_1 = pd.read_csv('13.4周期.csv')
data_1.head()
# Out:
#      T      H  Surge     Sway  Heave          Roll   Pitch           Yaw  \
# 0  0.1 -298.0  -2.01 -0.00086  -19.6  8.620000e-09 -0.0109  1.880000e-08
# 1  0.2 -367.0  -4.45  0.00356 -131.0 -7.040000e-07 -0.0321  1.370000e-08
# 2  0.3 -435.0  -5.51  0.02140 -344.0 -2.500000e-06 -0.0556 -9.810000e-07
# 3  0.4 -501.0 -13.50  0.04120 -460.0 -1.800000e-07 -0.0578 -2.480000e-06
# 4  0.5 -564.0 -27.80  0.05520 -450.0  1.370000e-06 -0.0481 -3.770000e-06
#
#    Force1  Force2
# 0  4900.0  5060.0
# 1  4620.0  5090.0
# 2  4230.0  5010.0
# 3  4060.0  4920.0
# 4  4070.0  4910.0

# %%
data_1.describe()
# Out:
#                   T             H         Surge          Sway         Heave  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean    2000.050030     -0.488046     42.388868     -0.012143    -28.808283
# std     1154.714989   1096.176784    453.484315      2.511379   1051.288924
# min        0.100000  -3560.000000  -2130.000000    -11.100000  -3590.000000
# 25%     1000.075015   -744.000000   -217.000000     -1.600000   -739.000000
# 50%     2000.050030     18.050000     29.200000     -0.010850    -18.250000
# 75%     3000.025045    737.000000    284.000000      1.620000    678.000000
# max     4000.000060   3710.000000   2020.000000     11.600000   3450.000000
#
#                Roll         Pitch           Yaw        Force1        Force2
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean       0.000002     -0.000469     -0.000006   5172.130532   4856.242250
# std        0.000419      0.041216      0.000405   2579.702616    685.105697
# min       -0.002660     -0.129000     -0.002340      0.000000   1720.000000
# 25%       -0.000256     -0.029300     -0.000231   3420.000000   4520.000000
# 50%        0.000001     -0.001260     -0.000004   5100.000000   4890.000000
# 75%        0.000263      0.027300      0.000219   6750.000000   5230.000000
# max        0.001950      0.150000      0.004010  15400.000000   9360.000000

# %%
data_distance = np.hstack((np.array(data_1)[:, 1:8], np.array(data_1)[:, 8:10]))
print(data_distance)
print(data_distance.shape)
# Out:
# [[-2.98e+02 -2.01e+00 -8.60e-04 ...  1.88e-08  4.90e+03  5.06e+03]
#  [-3.67e+02 -4.45e+00  3.56e-03 ...  1.37e-08  4.62e+03  5.09e+03]
#  [-4.35e+02 -5.51e+00  2.14e-02 ... -9.81e-07  4.23e+03  5.01e+03]
#  ...
#  [-1.50e+02  9.90e+01  1.49e+00 ... -1.13e-03  5.31e+03  4.47e+03]
#  [-1.15e+02  1.06e+02  3.01e+00 ... -1.12e-03  5.37e+03  4.44e+03]
#  [-7.88e+01  1.13e+02  3.94e+00 ... -1.07e-03  5.42e+03  4.42e+03]]
# (40000, 9)

# %%
H_scaler = MinMaxScaler(feature_range=(-1, 1))
H = H_scaler.fit_transform(data_distance[:,0:1])
Surge_scaler = MinMaxScaler(feature_range=(-1, 1))
Surge = Surge_scaler.fit_transform(data_distance[:,1:2])
Sway_scaler = MinMaxScaler(feature_range=(-1, 1))
Sway = Sway_scaler.fit_transform(data_distance[:,2:3])
Heave_scaler = MinMaxScaler(feature_range=(-1, 1))
Heave = Heave_scaler.fit_transform(data_distance[:,3:4])
Roll_scaler = MinMaxScaler(feature_range=(-1, 1))
Roll = Roll_scaler.fit_transform(data_distance[:,4:5]*1e6)
Pitch_scaler = MinMaxScaler(feature_range=(-1, 1))
Pitch = Pitch_scaler.fit_transform(data_distance[:,5:6])
Yaw_scaler = MinMaxScaler(feature_range=(-1, 1))
Yaw = Yaw_scaler.fit_transform(data_distance[:,6:7]*1e6)
Force1_scaler = MinMaxScaler(feature_range=(-1, 1))
Force1 = Force1_scaler.fit_transform(data_distance[:,7:8])
Force2_scaler = MinMaxScaler(feature_range=(-1, 1))
Force2 = Force2_scaler.fit_transform(data_distance[:,8:9])
# zong_data = np.hstack(())

# %%
def series_to_supervised(data, n_in, n_out, dropnan=True):
#      '''
#      说明：将每一个特征（输入+输出）的单步-目标步长数全数列举出来
#      '''
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    agg = concat(cols, axis=1)
    agg.columns = names
    if dropnan:
        agg.dropna(inplace=True)
    return agg
def deal_data1(data, features_number, time_steps):
    '''
    适用：单/多特征，单/多预测步长
    data：数据集（仅包括输入+输出，且输出仅有一列并在最后）
    feature_number：输入+输出变量数
    n_in：预测步长
    结果解释：输入+输出+所需预测步长的输出（当为单特征时，输入、输出为同一列）
    '''
    process_data = series_to_supervised(data, time_steps, 1, dropnan=True)
    a = []
    for i in range(features_number, features_number*(time_steps+1)-1):
        a.append(i)
        i = i+1
    process_data.drop(process_data.columns[a], axis=1, inplace=True)
    return process_data.values
def deal_data2(data, features_number, time_steps):
    '''
    适用：多特征，单/多预测步长，不适用于单特征
    data：数据集（仅包括输入+输出，且输出仅有一列并在最后）
    feature_number：输入+输出变量数
    n_in：预测步长
    结果解释：输入+所需预测步长的输出
    '''
    process_data = series_to_supervised(data, time_steps, 1, dropnan=True)
    a = []
    for i in range(features_number-1, features_number*(time_steps+1)-1):
        a.append(i)
        i = i+1
    process_data.drop(process_data.columns[a], axis=1, inplace=True)
    return process_data.values
def split_sequence(dataset, n_past):
    x, y = list(), list()
    for i in range(len(dataset)):
        end_ix = i + n_past
        if end_ix > len(dataset):
            break
        seq_x, seq_y = dataset[i:end_ix, :-1], dataset[i, -1]
        x.append(seq_x)
        y.append(seq_y)
    return np.array(x), np.array(y)

def loss_plot(history, epo, length, width):
    # plot history
    plt.figure(figsize = (length, width))
    # 将x周的刻度线方向设置向内
    plt.rcParams['xtick.direction'] = 'in'  
    # 将y轴的刻度方向设置向内
    plt.rcParams['ytick.direction'] = 'in'  
    #设置字体以便支持中文
    plt.rcParams['font.sans-serif']=['SimHei']
    #为正常显示负号
    plt.rcParams['axes.unicode_minus'] = False 
    plt.plot(history.history['loss'], label = 'train loss')
    plt.plot(history.history['val_loss'], label = 'valid loss')
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()
    print(np.hstack((np.array(history.history['loss']).reshape(epo,1), np.array(history.history['val_loss']).reshape(epo,1))))

from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,mean_absolute_percentage_error
def RNSE(valid_y,pre_Y):
    XP1 = valid_y.copy()
    XA1 = pre_Y.copy()
    print('RMSE(sklearn):',np.sqrt(mean_squared_error(XP1, XA1)))

def Acc(valid_y,pre_Y):
    XP1 = valid_y.copy()
    XA1 = pre_Y.copy()
    real1 = np.trapz(abs((XP1 - (XP1.sum()/(XP1.shape[0])))).reshape(XP1.shape[0],), dx=0.1)
    pre1 = np.trapz(abs((XA1 - (XP1.sum()/(XP1.shape[0])))).reshape(XA1.shape[0],), dx=0.1)
    Acc1 = 1 - abs(1 - (pre1/real1))
    print('Acc:', Acc1)

def FanGuiHua_surge(valid_sur_y,sur_pre_Y):
    fan_surge_real=Surge_scaler.inverse_transform(valid_sur_y)
    fan_surge_pre=Surge_scaler.inverse_transform(sur_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_surge_real[:200],color='blue',label='real')   #真实曲线
    plt.plot(fan_surge_pre[:200],color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_surge_real,fan_surge_pre)
    return fan_surge_real,fan_surge_pre
def FanGuiHua_pitch(valid_pit_y,pit_pre_Y):
    fan_pitch_real=Pitch_scaler.inverse_transform(valid_pit_y)
    fan_pitch_pre=Pitch_scaler.inverse_transform(pit_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_pitch_real[:200],color='blue',label='real')   #真实曲线
    plt.plot(fan_pitch_pre[:200],color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_pitch_real,fan_pitch_pre)
    return fan_pitch_real,fan_pitch_pre
def FanGuiHua_sway(valid_sway_y,sway_pre_Y):
    fan_sway_real=Sway_scaler.inverse_transform(valid_sway_y)
    fan_sway_pre=Sway_scaler.inverse_transform(sway_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_sway_real[:200],color='blue',label='real')   #真实曲线
    plt.plot(fan_sway_pre[:200],color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_sway_real,fan_sway_pre)
    return fan_sway_real,fan_sway_pre
def FanGuiHua_roll(valid_roll_y,roll_pre_Y):
    fan_roll_real=Roll_scaler.inverse_transform(valid_roll_y)
    fan_roll_pre=Roll_scaler.inverse_transform(roll_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_roll_real[:200],color='blue',label='real')   #真实曲线
    plt.plot(fan_roll_pre[:200],color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_roll_real,fan_roll_pre)
    return fan_roll_real,fan_roll_pre
def FanGuiHua_yaw(valid_yaw_y,yaw_pre_Y):
    fan_yaw_real=Yaw_scaler.inverse_transform(valid_yaw_y)
    fan_yaw_pre=Yaw_scaler.inverse_transform(yaw_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_yaw_real[:200],color='blue',label='real')   #真实曲线
    plt.plot(fan_yaw_pre[:200],color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_yaw_real,fan_yaw_pre)
    return fan_yaw_real,fan_yaw_pre
def FanGuiHua_heave(valid_hea_y,hea_pre_Y):
    fan_heave_real=Heave_scaler.inverse_transform(valid_hea_y)
    fan_heave_pre=Heave_scaler.inverse_transform(hea_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_heave_real[:200],color='blue',label='real')   #真实曲线
    plt.plot(fan_heave_pre[:200],color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_heave_real,fan_heave_pre)
    return fan_heave_real,fan_heave_pre
def FanGuiHua_force1(valid_for1_y,for1_pre_Y):
    fan_force1_real=Force1_scaler.inverse_transform(valid_for1_y)
    fan_force1_pre=Force1_scaler.inverse_transform(for1_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_force1_real,color='blue',label='real')   #真实曲线
    plt.plot(fan_force1_pre,color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_force1_real,fan_force1_pre)
    return fan_force1_real,fan_force1_pre
def FanGuiHua_force2(valid_for2_y,for2_pre_Y):
    fan_force2_real=Force2_scaler.inverse_transform(valid_for2_y)
    fan_force2_pre=Force2_scaler.inverse_transform(for2_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_force2_real,color='blue',label='real')   #真实曲线
    plt.plot(fan_force2_pre,color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_force2_real,fan_force2_pre)
    return fan_force2_real,fan_force2_pre

# 训练量=n_train_times_end-n_train_times_start
def split_train_valid(data_X, data_Y, n_train_times_start, n_train_times_end, n_valid_times):
    '''
    说明：将数据集划分为训练集和验证集
    疑问：先数据切割重组再划分数据集，先划分数据集再数据切割重组，有何区别影响？
    '''
    train_x, valid_x = data_X[n_train_times_start:n_train_times_end, :], data_X[n_train_times_end:n_valid_times, :]
    train_y, valid_y = data_Y[n_train_times_start:n_train_times_end], data_Y[n_train_times_end:n_valid_times]
    train_y = train_y.reshape((n_train_times_end-n_train_times_start, 1))
    valid_y = valid_y.reshape((n_valid_times-n_train_times_end, 1))
    return train_x, train_y, valid_x, valid_y

# %%
def Model_NN1(train_X, train_Y, valid_X, valid_Y, feature_number, lr=0.01, epochs=20, batch_size=256):
    input_layer = Input(shape=(feature_number,)) 
    D_layer1 = Dense(units = 150, activation = 'tanh')(input_layer)
    D_layer2 = Dense(units = 150, activation = 'tanh')(D_layer1)
    D_layer3 = Dense(units = 150, activation = 'tanh')(D_layer2)
    output_layer = Dense(1, activation = 'linear')(D_layer2)
    model = Model(inputs = input_layer, outputs = output_layer)
    adam = Adam(lr = lr)
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(train_X, train_Y, epochs=epochs, batch_size=batch_size, validation_data=(valid_X, valid_Y), verbose=2, shuffle=False)
    model_structure = model.summary()
    pre_train_Y = model.predict(train_X)
    pre_Y = model.predict(valid_X)
    return model, history, pre_train_Y, pre_Y

# %%
def Model_NN(train_X, train_Y, valid_X, valid_Y, lr=0.01, epochs=20, batch_size=256):
    model = Sequential() #初始化模型
    model.add(Dense(150,input_shape=(train_X.shape[1], ),activation='tanh')) #添加一个隐含层，注：只是第一个隐含层需指定input_dim
    model.add(Dense(150,activation='tanh'))
    model.add(Dense(150,activation='tanh'))
    model.add(Dense(1,activation='linear')) #添加输出层
    adam = Adam(lr = lr)
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(train_X, train_Y, epochs=epochs, batch_size=batch_size, validation_data=(valid_X, valid_Y), verbose=2, shuffle=False)
    model_structure = model.summary()
    pre_train_Y = model.predict(train_X)
    pre_Y = model.predict(valid_X)
    return model, history, pre_train_Y, pre_Y

# %%
# 归一化后的两个数据集
# 波浪-运动响应
# Force
# 输入500步长输出10步长
force150_scaled1 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[3500:,:], 4, 509)
force150_x1,force150_y1 = split_sequence(force150_scaled1, 500)
print(force150_x1.shape)
# # 输入100步长输出1步长
# force1100_scaled1 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[300:,:], 4, 100)
# force1100_x1,force1100_y1 = split_sequence(force1100_scaled1, 100)
# print(force1100_x1.shape)



# 输入500步长输出30步长
force150_scaled3 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[3480:,:], 4, 529)
force150_x3,force150_y3 = split_sequence(force150_scaled3, 500)
print(force150_x3.shape)
# # 输入100步长输出3步长
# force1100_scaled3 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[298:,:], 4, 102)
# force1100_x3,force1100_y3 = split_sequence(force1100_scaled3, 100)
# print(force1100_x3.shape)



# # 输入50步长输出5步长
# force150_scaled5 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[346:,:], 4, 54)
# force150_x5,force150_y5 = split_sequence(force150_scaled5, 50)
# print(force150_x5.shape)
# # 输入100步长输出5步长
# force1100_scaled5 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[296:,:], 4, 104)
# force1100_x5,force1100_y5 = split_sequence(force1100_scaled5, 100)
# print(force1100_x5.shape)



# # 输入50步长输出7步长
# force150_scaled7 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[344:,:], 4, 56)
# force150_x7,force150_y7 = split_sequence(force150_scaled7, 50)
# print(force150_x7.shape)
# # 输入100步长输出7步长
# force1100_scaled7 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[294:,:], 4, 106)
# force1100_x7,force1100_y7 = split_sequence(force1100_scaled7, 100)
# print(force1100_x7.shape)



# # 输入50步长输出9步长
# force150_scaled9 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[342:,:], 4, 58)
# force150_x9,force150_y9 = split_sequence(force150_scaled9, 50)
# print(force150_x9.shape)
# # 输入100步长输出9步长
# force1100_scaled9 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[292:,:], 4, 108)
# force1100_x9,force1100_y9 = split_sequence(force1100_scaled9, 100)
# print(force1100_x9.shape)



# 输入500步长输出20步长
force150_scaled2 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[3490:,:], 4, 519)
force150_x2,force150_y2 = split_sequence(force150_scaled2, 500)
print(force150_x2.shape)
# # 输入100步长输出2步长
# force1100_scaled2 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[299:,:], 4, 101)
# force1100_x2,force1100_y2 = split_sequence(force1100_scaled2, 100)
# print(force1100_x2.shape)


# 输入500步长输出40步长
force150_scaled4 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[3470:,:], 4, 539)
force150_x4,force150_y4 = split_sequence(force150_scaled4, 500)
print(force150_x4.shape)
# # 输入100步长输出4步长
# force1100_scaled4 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[297:,:], 4, 103)
# force1100_x4,force1100_y4 = split_sequence(force1100_scaled4, 100)
# print(force1100_x4.shape)



# # 输入50步长输出6步长
# force150_scaled6 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[345:,:], 4, 55)
# force150_x6,force150_y6 = split_sequence(force150_scaled6, 50)
# print(force150_x6.shape)
# # 输入100步长输出6步长
# force1100_scaled6 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[295:,:], 4, 105)
# force1100_x6,force1100_y6 = split_sequence(force1100_scaled6, 100)
# print(force1100_x6.shape)



# # 输入50步长输出8步长
# force150_scaled8 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[343:,:], 4, 57)
# force150_x8,force150_y8 = split_sequence(force150_scaled8, 50)
# print(force150_x8.shape)
# # 输入100步长输出8步长
# force1100_scaled8 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[293:,:], 4, 107)
# force1100_x8,force1100_y8 = split_sequence(force1100_scaled8, 100)
# print(force1100_x8.shape)
# Out:
# (35492, 500, 3)
# (35492, 500, 3)
# (35492, 500, 3)
# (35492, 500, 3)

# %%
print(force150_y1)
print(force150_y2)
print(force150_y3)
print(force150_y4)
# Out:
# [ 0.22987013  0.23376623  0.23506494 ... -0.01038961  0.02597403
#   0.05974026]
# [ 0.22987013  0.23376623  0.23506494 ... -0.01038961  0.02597403
#   0.05974026]
# [ 0.22987013  0.23376623  0.23506494 ... -0.01038961  0.02597403
#   0.05974026]
# [ 0.22987013  0.23376623  0.23506494 ... -0.01038961  0.02597403
#   0.05974026]

# %%
# 归一化后的两个数据集
# 波浪-运动响应
# 归一化后的两个数据集
# 波浪-运动响应
# Heave
# 输入500步长输出10步长
heave50_scaled1 = deal_data2(np.hstack((H,Heave))[3500:,:], 2, 509)
heave50_x1,heave50_y1 = split_sequence(heave50_scaled1, 500)
print(heave50_x1.shape)
# # 输入100步长输出1步长
# heave100_scaled1 = deal_data2(np.hstack((H,Heave))[300:,:], 2, 100)
# heave100_x1,heave100_y1 = split_sequence(heave100_scaled1, 100)
# print(heave100_x1.shape)



# 输入500步长输出30步长
heave50_scaled3 = deal_data2(np.hstack((H,Heave))[3480:,:], 2, 529)
heave50_x3,heave50_y3 = split_sequence(heave50_scaled3, 500)
print(heave50_x3.shape)
# # 输入100步长输出3步长
# heave100_scaled3 = deal_data2(np.hstack((H,Heave))[298:,:], 2, 102)
# heave100_x3,heave100_y3 = split_sequence(heave100_scaled3, 100)
# print(heave100_x3.shape)



# # 输入50步长输出5步长
# heave50_scaled5 = deal_data2(np.hstack((H,Heave))[346:,:], 2, 54)
# heave50_x5,heave50_y5 = split_sequence(heave50_scaled5, 50)
# print(heave50_x5.shape)
# # 输入100步长输出5步长
# heave100_scaled5 = deal_data2(np.hstack((H,Heave))[296:,:], 2, 104)
# heave100_x5,heave100_y5 = split_sequence(heave100_scaled5, 100)
# print(heave100_x5.shape)



# # 输入50步长输出7步长
# heave50_scaled7 = deal_data2(np.hstack((H,Heave))[344:,:], 2, 56)
# heave50_x7,heave50_y7 = split_sequence(heave50_scaled7, 50)
# print(heave50_x7.shape)
# # 输入100步长输出7步长
# heave100_scaled7 = deal_data2(np.hstack((H,Heave))[294:,:], 2, 106)
# heave100_x7,heave100_y7 = split_sequence(heave100_scaled7, 100)
# print(heave100_x7.shape)



# # 输入50步长输出9步长
# heave50_scaled9 = deal_data2(np.hstack((H,Heave))[342:,:], 2, 58)
# heave50_x9,heave50_y9 = split_sequence(heave50_scaled9, 50)
# print(heave50_x9.shape)
# # 输入100步长输出9步长
# heave100_scaled9 = deal_data2(np.hstack((H,Heave))[292:,:], 2, 108)
# heave100_x9,heave100_y9 = split_sequence(heave100_scaled9, 100)
# print(heave100_x9.shape)



# 输入500步长输出20步长
heave50_scaled2 = deal_data2(np.hstack((H,Heave))[3490:,:], 2, 519)
heave50_x2,heave50_y2 = split_sequence(heave50_scaled2, 500)
print(heave50_x2.shape)
# # 输入100步长输出2步长
# heave100_scaled2 = deal_data2(np.hstack((H,Heave))[299:,:], 2, 101)
# heave100_x2,heave100_y2 = split_sequence(heave100_scaled2, 100)
# print(heave100_x2.shape)


# 输入500步长输出40步长
heave50_scaled4 = deal_data2(np.hstack((H,Heave))[3470:,:], 2, 539)
heave50_x4,heave50_y4 = split_sequence(heave50_scaled4, 500)
print(heave50_x4.shape)
# # 输入100步长输出4步长
# heave100_scaled4 = deal_data2(np.hstack((H,Heave))[297:,:], 2, 103)
# heave100_x4,heave100_y4 = split_sequence(heave100_scaled4, 100)
# print(heave100_x4.shape)



# # 输入50步长输出6步长
# heave50_scaled6 = deal_data2(np.hstack((H,Heave))[345:,:], 2, 55)
# heave50_x6,heave50_y6 = split_sequence(heave50_scaled6, 50)
# print(heave50_x6.shape)
# # 输入100步长输出6步长
# heave100_scaled6 = deal_data2(np.hstack((H,Heave))[295:,:], 2, 105)
# heave100_x6,heave100_y6 = split_sequence(heave100_scaled6, 100)
# print(heave100_x6.shape)



# # 输入50步长输出8步长
# heave50_scaled8 = deal_data2(np.hstack((H,Heave))[343:,:], 2, 57)
# heave50_x8,heave50_y8 = split_sequence(heave50_scaled8, 50)
# print(heave50_x8.shape)
# # 输入100步长输出8步长
# heave100_scaled8 = deal_data2(np.hstack((H,Heave))[293:,:], 2, 107)
# heave100_x8,heave100_y8 = split_sequence(heave100_scaled8, 100)
# print(heave100_x8.shape)


# Surge
# 输入500步长输出10步长
surge50_scaled1 = deal_data2(np.hstack((H,Surge))[3500:,:], 2, 509)
surge50_x1,surge50_y1 = split_sequence(surge50_scaled1, 500)
print(surge50_x1.shape)
# # 输入100步长输出1步长
# surge100_scaled1 = deal_data2(np.hstack((H,Surge))[300:,:], 2, 100)
# surge100_x1,surge100_y1 = split_sequence(surge100_scaled1, 100)
# print(surge100_x1.shape)



# 输入500步长输出30步长
surge50_scaled3 = deal_data2(np.hstack((H,Surge))[3480:,:], 2, 529)
surge50_x3,surge50_y3 = split_sequence(surge50_scaled3, 500)
print(surge50_x3.shape)
# # 输入100步长输出3步长
# surge100_scaled3 = deal_data2(np.hstack((H,Surge))[298:,:], 2, 102)
# surge100_x3,surge100_y3 = split_sequence(surge100_scaled3, 100)
# print(surge100_x3.shape)



# # 输入50步长输出5步长
# surge50_scaled5 = deal_data2(np.hstack((H,Surge))[346:,:], 2, 54)
# surge50_x5,surge50_y5 = split_sequence(surge50_scaled5, 50)
# print(surge50_x5.shape)
# # 输入100步长输出5步长
# surge100_scaled5 = deal_data2(np.hstack((H,Surge))[296:,:], 2, 104)
# surge100_x5,surge100_y5 = split_sequence(surge100_scaled5, 100)
# print(surge100_x5.shape)



# # 输入50步长输出7步长
# surge50_scaled7 = deal_data2(np.hstack((H,Surge))[344:,:], 2, 56)
# surge50_x7,surge50_y7 = split_sequence(surge50_scaled7, 50)
# print(surge50_x7.shape)
# # 输入100步长输出7步长
# surge100_scaled7 = deal_data2(np.hstack((H,Surge))[294:,:], 2, 106)
# surge100_x7,surge100_y7 = split_sequence(surge100_scaled7, 100)
# print(surge100_x7.shape)



# # 输入50步长输出9步长
# surge50_scaled9 = deal_data2(np.hstack((H,Surge))[342:,:], 2, 58)
# surge50_x9,surge50_y9 = split_sequence(surge50_scaled9, 50)
# print(surge50_x9.shape)
# # 输入100步长输出9步长
# surge100_scaled9 = deal_data2(np.hstack((H,Surge))[292:,:], 2, 108)
# surge100_x9,surge100_y9 = split_sequence(surge100_scaled9, 100)
# print(surge100_x9.shape)



# 输入500步长输出20步长
surge50_scaled2 = deal_data2(np.hstack((H,Surge))[3490:,:], 2, 519)
surge50_x2,surge50_y2 = split_sequence(surge50_scaled2, 500)
print(surge50_x2.shape)
# 输入100步长输出2步长
# surge100_scaled2 = deal_data2(np.hstack((H,Surge))[299:,:], 2, 101)
# surge100_x2,surge100_y2 = split_sequence(surge100_scaled2, 100)
# print(surge100_x2.shape)


# 输入500步长输出40步长
surge50_scaled4 = deal_data2(np.hstack((H,Surge))[3470:,:], 2, 539)
surge50_x4,surge50_y4 = split_sequence(surge50_scaled4, 500)
print(surge50_x4.shape)
# # 输入100步长输出4步长
# surge100_scaled4 = deal_data2(np.hstack((H,Surge))[297:,:], 2, 103)
# surge100_x4,surge100_y4 = split_sequence(surge100_scaled4, 100)
# print(surge100_x4.shape)



# # 输入50步长输出6步长
# surge50_scaled6 = deal_data2(np.hstack((H,Surge))[345:,:], 2, 55)
# surge50_x6,surge50_y6 = split_sequence(surge50_scaled6, 50)
# print(surge50_x6.shape)
# # 输入100步长输出6步长
# surge100_scaled6 = deal_data2(np.hstack((H,Surge))[295:,:], 2, 105)
# surge100_x6,surge100_y6 = split_sequence(surge100_scaled6, 100)
# print(surge100_x6.shape)



# # 输入50步长输出8步长
# surge50_scaled8 = deal_data2(np.hstack((H,Surge))[343:,:], 2, 57)
# surge50_x8,surge50_y8 = split_sequence(surge50_scaled8, 50)
# print(surge50_x8.shape)
# # 输入100步长输出8步长
# surge100_scaled8 = deal_data2(np.hstack((H,Surge))[293:,:], 2, 107)
# surge100_x8,surge100_y8 = split_sequence(surge100_scaled8, 100)
# print(surge100_x8.shape)


# Pitch
# 输入500步长输出10步长
pitch50_scaled1 = deal_data2(np.hstack((H,Pitch))[3500:,:], 2, 509)
pitch50_x1,pitch50_y1 = split_sequence(pitch50_scaled1, 500)
print(pitch50_x1.shape)
# # 输入100步长输出1步长
# pitch100_scaled1 = deal_data2(np.hstack((H,Pitch))[300:,:], 2, 100)
# pitch100_x1,pitch100_y1 = split_sequence(pitch100_scaled1, 100)
# print(pitch100_x1.shape)



# 输入500步长输出30步长
pitch50_scaled3 = deal_data2(np.hstack((H,Pitch))[3480:,:], 2, 529)
pitch50_x3,pitch50_y3 = split_sequence(pitch50_scaled3, 500)
print(pitch50_x3.shape)
# # 输入100步长输出3步长
# pitch100_scaled3 = deal_data2(np.hstack((H,Pitch))[298:,:], 2, 102)
# pitch100_x3,pitch100_y3 = split_sequence(pitch100_scaled3, 100)
# print(pitch100_x3.shape)



# # 输入50步长输出5步长
# pitch50_scaled5 = deal_data2(np.hstack((H,Pitch))[346:,:], 2, 54)
# pitch50_x5,pitch50_y5 = split_sequence(pitch50_scaled5, 50)
# print(pitch50_x5.shape)
# # 输入100步长输出5步长
# pitch100_scaled5 = deal_data2(np.hstack((H,Pitch))[296:,:], 2, 104)
# pitch100_x5,pitch100_y5 = split_sequence(pitch100_scaled5, 100)
# print(pitch100_x5.shape)



# # 输入50步长输出7步长
# pitch50_scaled7 = deal_data2(np.hstack((H,Pitch))[344:,:], 2, 56)
# pitch50_x7,pitch50_y7 = split_sequence(pitch50_scaled7, 50)
# print(pitch50_x7.shape)
# # 输入100步长输出7步长
# pitch100_scaled7 = deal_data2(np.hstack((H,Pitch))[294:,:], 2, 106)
# pitch100_x7,pitch100_y7 = split_sequence(pitch100_scaled7, 100)
# print(pitch100_x7.shape)



# # 输入50步长输出9步长
# pitch50_scaled9 = deal_data2(np.hstack((H,Pitch))[342:,:], 2, 58)
# pitch50_x9,pitch50_y9 = split_sequence(pitch50_scaled9, 50)
# print(pitch50_x9.shape)
# # 输入100步长输出9步长
# pitch100_scaled9 = deal_data2(np.hstack((H,Pitch))[292:,:], 2, 108)
# pitch100_x9,pitch100_y9 = split_sequence(pitch100_scaled9, 100)
# print(pitch100_x9.shape)



# 输入500步长输出20步长
pitch50_scaled2 = deal_data2(np.hstack((H,Pitch))[3490:,:], 2, 519)
pitch50_x2,pitch50_y2 = split_sequence(pitch50_scaled2, 500)
print(pitch50_x2.shape)
# # 输入100步长输出2步长
# pitch100_scaled2 = deal_data2(np.hstack((H,Pitch))[299:,:], 2, 101)
# pitch100_x2,pitch100_y2 = split_sequence(pitch100_scaled2, 100)
# print(pitch100_x2.shape)


# 输入500步长输出40步长
pitch50_scaled4 = deal_data2(np.hstack((H,Pitch))[3470:,:], 2, 539)
pitch50_x4,pitch50_y4 = split_sequence(pitch50_scaled4, 500)
print(pitch50_x4.shape)
# # 输入100步长输出4步长
# pitch100_scaled4 = deal_data2(np.hstack((H,Pitch))[297:,:], 2, 103)
# pitch100_x4,pitch100_y4 = split_sequence(pitch100_scaled4, 100)
# print(pitch100_x4.shape)



# # 输入50步长输出6步长
# pitch50_scaled6 = deal_data2(np.hstack((H,Pitch))[345:,:], 2, 55)
# pitch50_x6,pitch50_y6 = split_sequence(pitch50_scaled6, 50)
# print(pitch50_x6.shape)
# # 输入100步长输出6步长
# pitch100_scaled6 = deal_data2(np.hstack((H,Pitch))[295:,:], 2, 105)
# pitch100_x6,pitch100_y6 = split_sequence(pitch100_scaled6, 100)
# print(pitch100_x6.shape)



# # 输入50步长输出8步长
# pitch50_scaled8 = deal_data2(np.hstack((H,Pitch))[343:,:], 2, 57)
# pitch50_x8,pitch50_y8 = split_sequence(pitch50_scaled8, 50)
# print(pitch50_x8.shape)
# # 输入100步长输出8步长
# pitch100_scaled8 = deal_data2(np.hstack((H,Pitch))[293:,:], 2, 107)
# pitch100_x8,pitch100_y8 = split_sequence(pitch100_scaled8, 100)
# print(pitch100_x8.shape)
# Out:
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)

# %% [markdown]
# ### 模型比较

# %%
# GRU
def Model_GRU(train_X, train_Y, valid_X, valid_Y, lr=0.01, epochs=20, batch_size=256):
    model = Sequential()
    model.add(GRU(25, activation='tanh', return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))  #25×5的数据输入
    model.add(Dropout(0.3))
    model.add(GRU(100, activation='tanh', return_sequences=True))
    model.add(Dropout(0.3))
    model.add(GRU(100, activation='tanh'))
    model.add(Dropout(0.3))
    model.add(Dense(train_Y.shape[1])) 
    model.add(Activation('tanh'))
    adam = Adam(lr = lr)
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(train_X, train_Y, epochs=epochs, batch_size=batch_size, validation_data=(valid_X, valid_Y), verbose=2, shuffle=False)
    model_structure = model.summary()
    pre_Y = model.predict(valid_X)
    return model, history, pre_Y

# LSTM
def Model_LSTM(train_X, train_Y, valid_X, valid_Y, lr=0.01, epochs=20, batch_size=256):
    model = Sequential()
    model.add(LSTM(25, activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2])))  #25×5的数据输入
    model.add(Dense(train_Y.shape[1])) 
    model.add(Activation('tanh'))
    adam = Adam(lr = lr)
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(train_X, train_Y, epochs=epochs, batch_size=batch_size, validation_data=(valid_X, valid_Y), verbose=2, shuffle=False)
    model_structure = model.summary()
    pre_Y = model.predict(valid_X)
    return model, history, pre_Y

# BiLSTM
from keras.layers import LeakyReLU
def Model_BiLSTM(train_X, train_Y, valid_X, valid_Y, lr=0.01, epochs=20, batch_size=256):
    model = Sequential()
    model.add(Bidirectional(LSTM(25, batch_input_shape=(24, train_X.shape[1], train_X.shape[2]),stateful=False), merge_mode='concat'))  #25×5的数据输入
    model.add(LeakyReLU(alpha=0.3))
    model.add(Dense(train_Y.shape[1])) 
    model.add(Activation('tanh'))
    adam = Adam(lr = lr)
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(train_X, train_Y, epochs=epochs, batch_size=batch_size, validation_data=(valid_X, valid_Y), verbose=2, shuffle=False)
    model_structure = model.summary()
    pre_Y = model.predict(valid_X)
    return model, history, pre_Y
# # Bi-StatefulLSTM
# def Model_BiSLSTM(train_X, train_Y, valid_X, valid_Y, lr=0.01, epochs=20, Batch_size=256):
#     model = Sequential() 
#     model.add(Bidirectional(LSTM(25, batch_input_shape=(24, train_X.shape[1], train_X.shape[2]),stateful=True,return_sequences=True), merge_mode='concat'))  
#     model.add(Bidirectional(LSTM(25,stateful=True), merge_mode='concat'))  
#     model.add(Dense(train_Y.shape[1])) 
#     model.add(Activation('tanh'))
#     adam = Adam(lr = lr)
#     model.compile(loss='mse', optimizer='adam')
#     history = model.fit(train_X, train_Y, epochs=epochs, batch_size=Batch_size, validation_data=(valid_X, valid_Y), verbose=2, shuffle=False)
#     model.reset_states()
#     model_structure = model.summary()
#     pre_Y = model.predict(valid_X,batch_size=Batch_size)
#     return model, history, pre_Y

# CNN-BiLSTM-Attention
from keras.layers import Input, Dense, LSTM, merge ,Conv1D, Dropout, Bidirectional, Multiply
from keras.models import Model
from attention_utils import get_activations
from keras.layers import merge
from keras.layers.core import *
from keras.layers.recurrent import LSTM
from keras.models import *
SINGLE_ATTENTION_VECTOR = False
def attention_3d_block(inputs):
    # inputs.shape = (batch_size, time_steps, input_dim)
    input_dim = int(inputs.shape[2])
    a = inputs
    #a = Permute((2, 1))(inputs)
    #a = Reshape((input_dim, TIME_STEPS))(a) # this line is not useful. It's just to know which dimension is what.
    a = Dense(input_dim, activation='softmax')(a)
    if SINGLE_ATTENTION_VECTOR:
        a = Lambda(lambda x: K.mean(x, axis=1), name='dim_reduction')(a)
        a = RepeatVector(input_dim)(a)
    a_probs = Permute((1, 2), name='attention_vec')(a)

    output_attention_mul = merge([inputs, a_probs], name='attention_mul', mode='mul')
    return output_attention_mul

# 注意力机制的另一种写法 适合上述报错使用 来源:https://blog.csdn.net/uhauha2929/article/details/80733255
def attention_3d_block2(inputs, single_attention_vector=False):
    # 如果上一层是LSTM，需要return_sequences=True
    # inputs.shape = (batch_size, time_steps, input_dim)
    time_steps = K.int_shape(inputs)[1]
    input_dim = K.int_shape(inputs)[2]
    a = Permute((2, 1))(inputs)
    a = Dense(time_steps, activation='tanh')(a)
    if single_attention_vector:
        a = Lambda(lambda x: K.mean(x, axis=1))(a)
        a = RepeatVector(input_dim)(a)

    a_probs = Permute((2, 1))(a)
    # 乘上了attention权重，但是并没有求和，好像影响不大
    # 如果分类任务，进行Flatten展开就可以了
    # element-wise
    output_attention_mul = Multiply()([inputs, a_probs])
    return output_attention_mul

def attention_model(train_X, train_Y, valid_X, valid_Y, lr=0.01, epochs=20, batch_size=256):
    inputs = Input(shape=(TIME_STEPS, INPUT_DIMS))

    x = Conv1D(filters = 64, kernel_size = 1, activation = 'tanh')(inputs)  #, padding = 'same'
    x = Dropout(0.1)(x)

    #lstm_out = Bidirectional(LSTM(lstm_units, activation='relu'), name='bilstm')(x)
    #对于GPU可以使用CuDNNLSTM
    lstm_out1 = LSTM(lstm_units, activation='tanh', return_sequences=True)(x)
#     lstm_out1 = LeakyReLU(alpha=0.3)(lstm_out1)
#     lstm_out1 = Dropout(0.3)(lstm_out1)
#     lstm_out2 = Bidirectional(LSTM(lstm_units, return_sequences=True))(lstm_out1)
#     lstm_out3 = LSTM(lstm_units)(lstm_out2)
#     lstm_out1 = Dropout(0.1)(lstm_out1)
    attention_mul = attention_3d_block2(lstm_out1)
    attention_mul = Flatten()(attention_mul)

    output = Dense(1)(attention_mul)
    model = Model(inputs=[inputs], outputs=output)
    adam = Adam(lr = lr)
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(train_X, train_Y, epochs=epochs, batch_size=batch_size, validation_data=(valid_X, valid_Y), verbose=2, shuffle=False)
    model.reset_states()
    model_structure = model.summary()
    pre_Y = model.predict(valid_X,batch_size=batch_size)
    return model, history, pre_Y

# %% [markdown]
# #### 系泊缆力联合预测（时间窗500输出；步长10）

# %%
train_heave50_x1, train_heave50_y1, valid_heave50_x1, valid_heave50_y1 = split_train_valid(heave50_x1,heave50_y1, 4500, 7500, 12000)
train_surge50_x1, train_surge50_y1, valid_surge50_x1, valid_surge50_y1 = split_train_valid(surge50_x1,surge50_y1, 4200, 7500, 12000)                                                             
train_pitch50_x1, train_pitch50_y1, valid_pitch50_x1, valid_pitch50_y1 = split_train_valid(pitch50_x1,pitch50_y1, 4500, 7500, 12000)

# %%
INPUT_DIMS = 1
TIME_STEPS = 500
lstm_units = 64
# 未来运动预测模型建立
heave50_model1, heave50_history1, pre_heave50_Y1 = attention_model(train_heave50_x1, train_heave50_y1, valid_heave50_x1, valid_heave50_y1, lr=0.1, epochs=30, batch_size=50)
# train_heave100_x1, train_heave100_y1, valid_heave100_x1, valid_heave100_y1 = split_train_valid(heave100_x1,heave100_y1, 6900, 7500, 8000)
# heave100_model1, heave100_history1, pre_heave100_Y1 = Model_LSTM(train_heave100_x1, train_heave100_y1, valid_heave100_x1, valid_heave100_y1, lr=0.1, epochs=60, batch_size=50)

surge50_model1, surge50_history1, pre_surge50_Y1 = attention_model(train_surge50_x1, train_surge50_y1, valid_surge50_x1, valid_surge50_y1, lr=1.3, epochs=30, batch_size=50)
# train_surge100_x1, train_surge100_y1, valid_surge100_x1, valid_surge100_y1 = split_train_valid(surge100_x1,surge100_y1, 6600, 7500, 8000)
# surge100_model1, surge100_history1, pre_surge100_Y1 = Model_LSTM(train_surge100_x1, train_surge100_y1, valid_surge100_x1, valid_surge100_y1, lr=1.3, epochs=60, batch_size=50)
                                                                 
pitch50_model1, pitch50_history1, pre_pitch50_Y1 = attention_model(train_pitch50_x1, train_pitch50_y1, valid_pitch50_x1, valid_pitch50_y1, lr=0.35, epochs=30, batch_size=50)
# train_pitch100_x1, train_pitch100_y1, valid_pitch100_x1, valid_pitch100_y1 = split_train_valid(pitch100_x1,pitch100_y1, 6900, 7500, 8000)
# pitch100_model1, pitch100_history1, pre_pitch100_Y1 = Model_LSTM(train_pitch100_x1, train_pitch100_y1, valid_pitch100_x1, valid_pitch100_y1, lr=0.35, epochs=60, batch_size=50)
# Out:
# Train on 3000 samples, validate on 4500 samples
# Epoch 1/30
#  - 45s - loss: 0.0708 - val_loss: 0.0388
# Epoch 2/30
#  - 47s - loss: 0.0306 - val_loss: 0.0240
# Epoch 3/30
#  - 47s - loss: 0.0200 - val_loss: 0.0170
# Epoch 4/30
#  - 49s - loss: 0.0163 - val_loss: 0.0151
# Epoch 5/30
#  - 49s - loss: 0.0162 - val_loss: 0.0164
# Epoch 6/30
#  - 51s - loss: 0.0163 - val_loss: 0.0129
# Epoch 7/30
#  - 51s - loss: 0.0128 - val_loss: 0.0122
# Epoch 8/30
#  - 53s - loss: 0.0078 - val_loss: 0.0123
# Epoch 9/30
#  - 51s - loss: 0.0083 - val_loss: 0.0120
# Epoch 10/30
#  - 52s - loss: 0.0077 - val_loss: 0.0123
# Epoch 11/30
#  - 51s - loss: 0.0086 - val_loss: 0.0117
# Epoch 12/30
#  - 53s - loss: 0.0097 - val_loss: 0.0105
# Epoch 13/30
#  - 53s - loss: 0.0067 - val_loss: 0.0104
# Epoch 14/30
#  - 53s - loss: 0.0067 - val_loss: 0.0094
# Epoch 15/30
#  - 52s - loss: 0.0062 - val_loss: 0.0109
# Epoch 16/30
#  - 49s - loss: 0.0060 - val_loss: 0.0089
# Epoch 17/30
#  - 46s - loss: 0.0053 - val_loss: 0.0088
# Epoch 18/30
#  - 39s - loss: 0.0052 - val_loss: 0.0134
# Epoch 19/30
#  - 47s - loss: 0.0059 - val_loss: 0.0094
# Epoch 20/30
#  - 49s - loss: 0.0062 - val_loss: 0.0094
# Epoch 21/30
#  - 49s - loss: 0.0052 - val_loss: 0.0104
# Epoch 22/30
#  - 49s - loss: 0.0053 - val_loss: 0.0088
# Epoch 23/30
#  - 48s - loss: 0.0065 - val_loss: 0.0099
# Epoch 24/30
#  - 40s - loss: 0.0084 - val_loss: 0.0105
# Epoch 25/30
#  - 47s - loss: 0.0066 - val_loss: 0.0128
# Epoch 26/30
#  - 49s - loss: 0.0061 - val_loss: 0.0146
# Epoch 27/30
#  - 51s - loss: 0.0046 - val_loss: 0.0102
# Epoch 28/30
#  - 51s - loss: 0.0038 - val_loss: 0.0092
# Epoch 29/30
#  - 51s - loss: 0.0041 - val_loss: 0.0090
# Epoch 30/30
#  - 51s - loss: 0.0046 - val_loss: 0.0079
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 500, 1)       0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 500, 64)      128         input_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 500, 64)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 500, 64)      33024       dropout_1[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 64, 500)      0           lstm_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64, 500)      250500      permute_1[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 500, 64)      0           dense_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 500, 64)      0           lstm_1[0][0]
#                                                                  permute_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 32000)        0           multiply_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            32001       flatten_1[0][0]
# ==================================================================================================
# Total params: 315,653
# Trainable params: 315,653
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 3300 samples, validate on 4500 samples
# Epoch 1/30
#  - 56s - loss: 0.0322 - val_loss: 0.0274
# Epoch 2/30
#  - 57s - loss: 0.0171 - val_loss: 0.0142
# Epoch 3/30
#  - 60s - loss: 0.0153 - val_loss: 0.0236
# Epoch 4/30
#  - 58s - loss: 0.0160 - val_loss: 0.0127
# Epoch 5/30
#  - 53s - loss: 0.0142 - val_loss: 0.0103
# Epoch 6/30
#  - 56s - loss: 0.0102 - val_loss: 0.0139
# Epoch 7/30
#  - 58s - loss: 0.0064 - val_loss: 0.0106
# Epoch 8/30
#  - 57s - loss: 0.0071 - val_loss: 0.0092
# Epoch 9/30
#  - 60s - loss: 0.0061 - val_loss: 0.0095
# Epoch 10/30
#  - 60s - loss: 0.0062 - val_loss: 0.0095
# Epoch 11/30
#  - 59s - loss: 0.0045 - val_loss: 0.0096
# Epoch 12/30
#  - 60s - loss: 0.0047 - val_loss: 0.0103
# Epoch 13/30
#  - 61s - loss: 0.0036 - val_loss: 0.0104
# Epoch 14/30
#  - 60s - loss: 0.0035 - val_loss: 0.0098
# Epoch 15/30
#  - 57s - loss: 0.0041 - val_loss: 0.0112
# Epoch 16/30
#  - 61s - loss: 0.0034 - val_loss: 0.0125
# Epoch 17/30
#  - 60s - loss: 0.0030 - val_loss: 0.0101
# Epoch 18/30
#  - 60s - loss: 0.0037 - val_loss: 0.0100
# Epoch 19/30
#  - 62s - loss: 0.0033 - val_loss: 0.0090
# Epoch 20/30
#  - 55s - loss: 0.0027 - val_loss: 0.0095
# Epoch 21/30
#  - 60s - loss: 0.0025 - val_loss: 0.0097
# Epoch 22/30
#  - 63s - loss: 0.0023 - val_loss: 0.0100
# Epoch 23/30
#  - 62s - loss: 0.0019 - val_loss: 0.0099
# Epoch 24/30
#  - 61s - loss: 0.0017 - val_loss: 0.0104
# Epoch 25/30
#  - 62s - loss: 0.0017 - val_loss: 0.0104
# Epoch 26/30
#  - 62s - loss: 0.0015 - val_loss: 0.0099
# Epoch 27/30
#  - 63s - loss: 0.0016 - val_loss: 0.0113
# Epoch 28/30
#  - 61s - loss: 0.0018 - val_loss: 0.0094
# Epoch 29/30
#  - 62s - loss: 0.0028 - val_loss: 0.0108
# Epoch 30/30
#  - 61s - loss: 0.0029 - val_loss: 0.0105
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 500, 1)       0
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 500, 64)      128         input_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 500, 64)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 500, 64)      33024       dropout_2[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 64, 500)      0           lstm_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64, 500)      250500      permute_3[0][0]
# __________________________________________________________________________________________________
# permute_4 (Permute)             (None, 500, 64)      0           dense_3[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 500, 64)      0           lstm_2[0][0]
#                                                                  permute_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 32000)        0           multiply_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            32001       flatten_2[0][0]
# ==================================================================================================
# Total params: 315,653
# Trainable params: 315,653
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 3000 samples, validate on 4500 samples
# Epoch 1/30
#  - 57s - loss: 0.0719 - val_loss: 0.0629
# Epoch 2/30
#  - 56s - loss: 0.0448 - val_loss: 0.0409
# Epoch 3/30
#  - 59s - loss: 0.0355 - val_loss: 0.0381
# Epoch 4/30
#  - 56s - loss: 0.0298 - val_loss: 0.0345
# Epoch 5/30
#  - 59s - loss: 0.0275 - val_loss: 0.0410
# Epoch 6/30
#  - 62s - loss: 0.0268 - val_loss: 0.0401
# Epoch 7/30
#  - 63s - loss: 0.0249 - val_loss: 0.0347
# Epoch 8/30
#  - 63s - loss: 0.0234 - val_loss: 0.0343
# Epoch 9/30
#  - 62s - loss: 0.0241 - val_loss: 0.0388
# Epoch 10/30
#  - 62s - loss: 0.0241 - val_loss: 0.0416
# Epoch 11/30
#  - 63s - loss: 0.0226 - val_loss: 0.0374
# Epoch 12/30
#  - 64s - loss: 0.0197 - val_loss: 0.0502
# Epoch 13/30
#  - 62s - loss: 0.0253 - val_loss: 0.0417
# Epoch 14/30
#  - 62s - loss: 0.0228 - val_loss: 0.0458
# Epoch 15/30
#  - 60s - loss: 0.0228 - val_loss: 0.0430
# Epoch 16/30
#  - 63s - loss: 0.0246 - val_loss: 0.0495
# Epoch 17/30
#  - 62s - loss: 0.0257 - val_loss: 0.0456
# Epoch 18/30
#  - 61s - loss: 0.0214 - val_loss: 0.0476
# Epoch 19/30
#  - 57s - loss: 0.0257 - val_loss: 0.0377
# Epoch 20/30
#  - 60s - loss: 0.0168 - val_loss: 0.0455
# Epoch 21/30
#  - 62s - loss: 0.0209 - val_loss: 0.0511
# Epoch 22/30
#  - 64s - loss: 0.0168 - val_loss: 0.0467
# Epoch 23/30
#  - 63s - loss: 0.0207 - val_loss: 0.0440
# Epoch 24/30
#  - 59s - loss: 0.0156 - val_loss: 0.0439
# Epoch 25/30
#  - 63s - loss: 0.0145 - val_loss: 0.0535
# Epoch 26/30
#  - 62s - loss: 0.0160 - val_loss: 0.0534
# Epoch 27/30
#  - 63s - loss: 0.0190 - val_loss: 0.0559
# Epoch 28/30
#  - 62s - loss: 0.0246 - val_loss: 0.0573
# Epoch 29/30
#  - 62s - loss: 0.0218 - val_loss: 0.0403
# Epoch 30/30
#  - 61s - loss: 0.0171 - val_loss: 0.0536
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 500, 1)       0
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 500, 64)      128         input_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 500, 64)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 500, 64)      33024       dropout_3[0][0]
# __________________________________________________________________________________________________
# permute_5 (Permute)             (None, 64, 500)      0           lstm_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64, 500)      250500      permute_5[0][0]
# __________________________________________________________________________________________________
# permute_6 (Permute)             (None, 500, 64)      0           dense_5[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 500, 64)      0           lstm_3[0][0]
#                                                                  permute_6[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 32000)        0           multiply_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            32001       flatten_3[0][0]
# ==================================================================================================
# Total params: 315,653
# Trainable params: 315,653
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
pretrain_heave50_Y1 = heave50_model1.predict(train_heave50_x1)
# pretrain_heave100_Y1 = heave100_model1.predict(train_heave100_x1)

pretrain_surge50_Y1 = surge50_model1.predict(train_surge50_x1[300:,:])
# pretrain_surge100_Y1 = surge100_model1.predict(train_surge100_x1)

pretrain_pitch50_Y1 = pitch50_model1.predict(train_pitch50_x1)
# pretrain_pitch100_Y1 = pitch100_model1.predict(train_pitch100_x1)
print(pretrain_heave50_Y1.shape)
print(pretrain_surge50_Y1.shape)
print(pretrain_pitch50_Y1.shape)
# Out:
# (3000, 1)
# (3000, 1)
# (3000, 1)

# %%
pre_heave50_Y1 = heave50_model1.predict(valid_heave50_x1)
# pretrain_heave100_Y1 = heave100_model1.predict(train_heave100_x1)

pre_surge50_Y1 = surge50_model1.predict(valid_surge50_x1)
# pretrain_surge100_Y1 = surge100_model1.predict(train_surge100_x1)

pre_pitch50_Y1 = pitch50_model1.predict(valid_pitch50_x1)
# pretrain_pitch100_Y1 = pitch100_model1.predict(train_pitch100_x1)
print(pre_heave50_Y1.shape)
print(pre_surge50_Y1.shape)
print(pre_pitch50_Y1.shape)
# Out:
# (4500, 1)
# (4500, 1)
# (4500, 1)

# %%
# 输入500步长输出10步长Force1
force150_scaled1 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[3500:,:], 4, 509)
force150_x1,force150_y1 = split_sequence(force150_scaled1, 500)
# print(force150_x1.shape)
# 输入100步长输出1步长
# force1100_scaled1 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[300:,:], 4, 100)
# force1100_x1,force1100_y1 = split_sequence(force1100_scaled1, 100)
# print(force1100_x1.shape)

# %%
train_force150_x1, train_force150_y1, valid_force150_x1, valid_force150_y1 = split_train_valid(force150_x1,force150_y1, 4500, 7500, 12000)
train50_x_Force1, valid50_x_Force1 = np.hstack((pretrain_heave50_Y1, pretrain_surge50_Y1, pretrain_pitch50_Y1)), np.hstack((pre_heave50_Y1, pre_surge50_Y1, pre_pitch50_Y1))
train50_y_Force1, valid50_y_Force1 = train_force150_y1, valid_force150_y1

# %%
N_model50_Force1, N_history50_Force1, N_pre50_train_Y_Force1, N_pre50_Y_Force1 = Model_NN(train50_x_Force1, train50_y_Force1, valid50_x_Force1, valid50_y_Force1, lr=0.01, epochs=1000, batch_size=256)
# Out:
# Train on 3000 samples, validate on 4500 samples
# Epoch 1/1000
#  - 0s - loss: 0.0725 - val_loss: 0.0209
# Epoch 2/1000
#  - 0s - loss: 0.0142 - val_loss: 0.0199
# Epoch 3/1000
#  - 0s - loss: 0.0069 - val_loss: 0.0206
# Epoch 4/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0184
# Epoch 5/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0188
# Epoch 6/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0186
# Epoch 7/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0179
# Epoch 8/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0177
# Epoch 9/1000
#  - 0s - loss: 0.0067 - val_loss: 0.0179
# Epoch 10/1000
#  - 0s - loss: 0.0079 - val_loss: 0.0182
# Epoch 11/1000
#  - 0s - loss: 0.0082 - val_loss: 0.0174
# Epoch 12/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0187
# Epoch 13/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0195
# Epoch 14/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0186
# Epoch 15/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0180
# Epoch 16/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0181
# Epoch 17/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0184
# Epoch 18/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0184
# Epoch 19/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0181
# Epoch 20/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0180
# Epoch 21/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0180
# Epoch 22/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0179
# Epoch 23/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0179
# Epoch 24/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0178
# Epoch 25/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0177
# Epoch 26/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0177
# Epoch 27/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0177
# Epoch 28/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0178
# Epoch 29/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0178
# Epoch 30/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0179
# Epoch 31/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0179
# Epoch 32/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0179
# Epoch 33/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0179
# Epoch 34/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0179
# Epoch 35/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0179
# Epoch 36/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0178
# Epoch 37/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0177
# Epoch 38/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0177
# Epoch 39/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0177
# Epoch 40/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0177
# Epoch 41/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0177
# Epoch 42/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0178
# Epoch 43/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0180
# Epoch 44/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0183
# Epoch 45/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0186
# Epoch 46/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0192
# Epoch 47/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0202
# Epoch 48/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0217
# Epoch 49/1000
#  - 0s - loss: 0.0068 - val_loss: 0.0223
# Epoch 50/1000
#  - 0s - loss: 0.0067 - val_loss: 0.0207
# Epoch 51/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0193
# Epoch 52/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0190
# Epoch 53/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 54/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0188
# Epoch 55/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0184
# Epoch 56/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0183
# Epoch 57/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0183
# Epoch 58/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0182
# Epoch 59/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0181
# Epoch 60/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0181
# Epoch 61/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0181
# Epoch 62/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0181
# Epoch 63/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0180
# Epoch 64/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0180
# Epoch 65/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0180
# Epoch 66/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0180
# Epoch 67/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0180
# Epoch 68/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0179
# Epoch 69/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0179
# Epoch 70/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0180
# Epoch 71/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0181
# Epoch 72/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0182
# Epoch 73/1000
#  - 0s - loss: 0.0066 - val_loss: 0.0184
# Epoch 74/1000
#  - 0s - loss: 0.0067 - val_loss: 0.0183
# Epoch 75/1000
#  - 0s - loss: 0.0064 - val_loss: 0.0181
# Epoch 76/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0181
# Epoch 77/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0185
# Epoch 78/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0193
# Epoch 79/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0200
# Epoch 80/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0203
# Epoch 81/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0200
# Epoch 82/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0196
# Epoch 83/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0193
# Epoch 84/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 85/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 86/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 87/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 88/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 89/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 90/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 91/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 92/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 93/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 94/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 95/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 96/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 97/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 98/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 99/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 100/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 101/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 102/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 103/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 104/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 105/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 106/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 107/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 108/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 109/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 110/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 111/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 112/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 113/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 114/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 115/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 116/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 117/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 118/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 119/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 120/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 121/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 122/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 123/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 124/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 125/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 126/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 127/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0189
# Epoch 128/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 129/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 130/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 131/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 132/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 133/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 134/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 135/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 136/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 137/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 138/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 139/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 140/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 141/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0190
# Epoch 142/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 143/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 144/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 145/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 146/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 147/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 148/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 149/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 150/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 151/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 152/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 153/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0191
# Epoch 154/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0192
# Epoch 155/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0192
# Epoch 156/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0192
# Epoch 157/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0192
# Epoch 158/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0192
# Epoch 159/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0192
# Epoch 160/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0192
# Epoch 161/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0192
# Epoch 162/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0192
# Epoch 163/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0192
# Epoch 164/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0193
# Epoch 165/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0193
# Epoch 166/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0193
# Epoch 167/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0193
# Epoch 168/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0194
# Epoch 169/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0194
# Epoch 170/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0194
# Epoch 171/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0194
# Epoch 172/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0193
# Epoch 173/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0193
# Epoch 174/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0194
# Epoch 175/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0194
# Epoch 176/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0196
# Epoch 177/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0197
# Epoch 178/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0197
# Epoch 179/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0196
# Epoch 180/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0194
# Epoch 181/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0192
# Epoch 182/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0192
# Epoch 183/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0194
# Epoch 184/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0198
# Epoch 185/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0204
# Epoch 186/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0206
# Epoch 187/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0202
# Epoch 188/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0193
# Epoch 189/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0186
# Epoch 190/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0186
# Epoch 191/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0194
# Epoch 192/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0207
# Epoch 193/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0216
# Epoch 194/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0208
# Epoch 195/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0193
# Epoch 196/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0184
# Epoch 197/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0184
# Epoch 198/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0196
# Epoch 199/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0211
# Epoch 200/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0213
# Epoch 201/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0201
# Epoch 202/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0190
# Epoch 203/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0185
# Epoch 204/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0192
# Epoch 205/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0205
# Epoch 206/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0215
# Epoch 207/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0212
# Epoch 208/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0199
# Epoch 209/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0189
# Epoch 210/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0188
# Epoch 211/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0198
# Epoch 212/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0212
# Epoch 213/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0220
# Epoch 214/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0210
# Epoch 215/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0195
# Epoch 216/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0187
# Epoch 217/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0192
# Epoch 218/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0209
# Epoch 219/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0222
# Epoch 220/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0216
# Epoch 221/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0201
# Epoch 222/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0190
# Epoch 223/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0192
# Epoch 224/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0209
# Epoch 225/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0223
# Epoch 226/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0217
# Epoch 227/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0207
# Epoch 228/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0199
# Epoch 229/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0211
# Epoch 230/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0230
# Epoch 231/1000
#  - 0s - loss: 0.0065 - val_loss: 0.0230
# Epoch 232/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0219
# Epoch 233/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0204
# Epoch 234/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0195
# Epoch 235/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0194
# Epoch 236/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0202
# Epoch 237/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0197
# Epoch 238/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0192
# Epoch 239/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0192
# Epoch 240/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0195
# Epoch 241/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 242/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 243/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0198
# Epoch 244/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0197
# Epoch 245/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0198
# Epoch 246/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0200
# Epoch 247/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0201
# Epoch 248/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0199
# Epoch 249/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0197
# Epoch 250/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0197
# Epoch 251/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0198
# Epoch 252/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 253/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 254/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0198
# Epoch 255/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0198
# Epoch 256/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0198
# Epoch 257/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 258/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0200
# Epoch 259/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0199
# Epoch 260/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0198
# Epoch 261/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0198
# Epoch 262/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 263/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 264/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 265/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 266/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0198
# Epoch 267/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 268/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 269/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 270/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 271/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 272/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 273/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 274/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 275/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 276/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 277/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 278/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 279/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 280/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 281/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 282/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 283/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 284/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 285/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 286/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 287/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 288/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 289/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 290/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 291/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 292/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 293/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 294/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 295/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 296/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 297/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 298/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 299/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0201
# Epoch 300/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 301/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 302/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0198
# Epoch 303/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 304/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 305/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0201
# Epoch 306/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0201
# Epoch 307/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 308/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0198
# Epoch 309/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0198
# Epoch 310/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 311/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0201
# Epoch 312/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0202
# Epoch 313/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0202
# Epoch 314/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 315/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0197
# Epoch 316/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0196
# Epoch 317/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0198
# Epoch 318/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0202
# Epoch 319/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0205
# Epoch 320/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0204
# Epoch 321/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0200
# Epoch 322/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0196
# Epoch 323/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0194
# Epoch 324/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0198
# Epoch 325/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0204
# Epoch 326/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0208
# Epoch 327/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0205
# Epoch 328/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0198
# Epoch 329/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0193
# Epoch 330/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0194
# Epoch 331/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0201
# Epoch 332/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0209
# Epoch 333/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0207
# Epoch 334/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 335/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0193
# Epoch 336/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0193
# Epoch 337/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0201
# Epoch 338/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0208
# Epoch 339/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0205
# Epoch 340/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0198
# Epoch 341/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0193
# Epoch 342/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0195
# Epoch 343/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0204
# Epoch 344/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0208
# Epoch 345/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0202
# Epoch 346/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0196
# Epoch 347/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0193
# Epoch 348/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0199
# Epoch 349/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0206
# Epoch 350/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0206
# Epoch 351/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 352/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0194
# Epoch 353/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0195
# Epoch 354/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0202
# Epoch 355/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0207
# Epoch 356/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0203
# Epoch 357/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0197
# Epoch 358/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0193
# Epoch 359/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0196
# Epoch 360/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0204
# Epoch 361/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0206
# Epoch 362/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0200
# Epoch 363/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0195
# Epoch 364/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0193
# Epoch 365/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0198
# Epoch 366/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0204
# Epoch 367/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0204
# Epoch 368/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0199
# Epoch 369/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0194
# Epoch 370/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0193
# Epoch 371/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0198
# Epoch 372/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0204
# Epoch 373/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0203
# Epoch 374/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0198
# Epoch 375/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0193
# Epoch 376/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0193
# Epoch 377/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0197
# Epoch 378/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0201
# Epoch 379/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0198
# Epoch 380/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0194
# Epoch 381/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0191
# Epoch 382/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0192
# Epoch 383/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0198
# Epoch 384/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0206
# Epoch 385/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0203
# Epoch 386/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0198
# Epoch 387/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0195
# Epoch 388/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0199
# Epoch 389/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0205
# Epoch 390/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0206
# Epoch 391/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0202
# Epoch 392/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0197
# Epoch 393/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0196
# Epoch 394/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0201
# Epoch 395/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0204
# Epoch 396/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0202
# Epoch 397/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0198
# Epoch 398/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0194
# Epoch 399/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0195
# Epoch 400/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0199
# Epoch 401/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0200
# Epoch 402/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0196
# Epoch 403/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0193
# Epoch 404/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0192
# Epoch 405/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0194
# Epoch 406/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0198
# Epoch 407/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0199
# Epoch 408/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0197
# Epoch 409/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0196
# Epoch 410/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0197
# Epoch 411/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0200
# Epoch 412/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0203
# Epoch 413/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0206
# Epoch 414/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0208
# Epoch 415/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0208
# Epoch 416/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0206
# Epoch 417/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0200
# Epoch 418/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0195
# Epoch 419/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0194
# Epoch 420/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0194
# Epoch 421/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0193
# Epoch 422/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0194
# Epoch 423/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0197
# Epoch 424/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0199
# Epoch 425/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0199
# Epoch 426/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0198
# Epoch 427/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0196
# Epoch 428/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0195
# Epoch 429/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0195
# Epoch 430/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0193
# Epoch 431/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0192
# Epoch 432/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0193
# Epoch 433/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0195
# Epoch 434/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0198
# Epoch 435/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0200
# Epoch 436/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0199
# Epoch 437/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0198
# Epoch 438/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0198
# Epoch 439/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0200
# Epoch 440/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0200
# Epoch 441/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0198
# Epoch 442/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0194
# Epoch 443/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0192
# Epoch 444/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0192
# Epoch 445/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0193
# Epoch 446/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0195
# Epoch 447/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0195
# Epoch 448/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0198
# Epoch 449/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0201
# Epoch 450/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0201
# Epoch 451/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0199
# Epoch 452/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0198
# Epoch 453/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0197
# Epoch 454/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0196
# Epoch 455/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0193
# Epoch 456/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0192
# Epoch 457/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0192
# Epoch 458/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0195
# Epoch 459/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0197
# Epoch 460/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0198
# Epoch 461/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0198
# Epoch 462/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0199
# Epoch 463/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0200
# Epoch 464/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0201
# Epoch 465/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0202
# Epoch 466/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0203
# Epoch 467/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0205
# Epoch 468/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0209
# Epoch 469/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0219
# Epoch 470/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0229
# Epoch 471/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0221
# Epoch 472/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0205
# Epoch 473/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0197
# Epoch 474/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0195
# Epoch 475/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0204
# Epoch 476/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0205
# Epoch 477/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0192
# Epoch 478/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0193
# Epoch 479/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0199
# Epoch 480/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0201
# Epoch 481/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0194
# Epoch 482/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0197
# Epoch 483/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0196
# Epoch 484/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0197
# Epoch 485/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0194
# Epoch 486/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0194
# Epoch 487/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0195
# Epoch 488/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0195
# Epoch 489/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0194
# Epoch 490/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0194
# Epoch 491/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0195
# Epoch 492/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0195
# Epoch 493/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0194
# Epoch 494/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0194
# Epoch 495/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0194
# Epoch 496/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0194
# Epoch 497/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0193
# Epoch 498/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0193
# Epoch 499/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0194
# Epoch 500/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0194
# Epoch 501/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0194
# Epoch 502/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0195
# Epoch 503/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0197
# Epoch 504/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0200
# Epoch 505/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0204
# Epoch 506/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 507/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0216
# Epoch 508/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0234
# Epoch 509/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0247
# Epoch 510/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0227
# Epoch 511/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0210
# Epoch 512/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0202
# Epoch 513/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0200
# Epoch 514/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0205
# Epoch 515/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0193
# Epoch 516/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0196
# Epoch 517/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0197
# Epoch 518/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0198
# Epoch 519/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0196
# Epoch 520/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0198
# Epoch 521/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0198
# Epoch 522/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0197
# Epoch 523/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0197
# Epoch 524/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0198
# Epoch 525/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0200
# Epoch 526/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0203
# Epoch 527/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 528/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0221
# Epoch 529/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0223
# Epoch 530/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0204
# Epoch 531/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0194
# Epoch 532/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0199
# Epoch 533/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0203
# Epoch 534/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0195
# Epoch 535/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0198
# Epoch 536/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0198
# Epoch 537/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0198
# Epoch 538/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0198
# Epoch 539/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0200
# Epoch 540/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0203
# Epoch 541/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0205
# Epoch 542/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0208
# Epoch 543/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 544/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0209
# Epoch 545/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0203
# Epoch 546/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0198
# Epoch 547/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0198
# Epoch 548/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0200
# Epoch 549/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0203
# Epoch 550/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 551/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0216
# Epoch 552/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0219
# Epoch 553/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0212
# Epoch 554/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0201
# Epoch 555/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0196
# Epoch 556/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0200
# Epoch 557/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0203
# Epoch 558/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0205
# Epoch 559/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 560/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 561/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 562/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0207
# Epoch 563/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0204
# Epoch 564/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0203
# Epoch 565/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0204
# Epoch 566/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 567/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0213
# Epoch 568/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0216
# Epoch 569/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0213
# Epoch 570/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0207
# Epoch 571/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0201
# Epoch 572/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0201
# Epoch 573/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0205
# Epoch 574/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0210
# Epoch 575/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0215
# Epoch 576/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0217
# Epoch 577/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 578/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0204
# Epoch 579/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0201
# Epoch 580/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0203
# Epoch 581/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 582/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0213
# Epoch 583/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0216
# Epoch 584/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0213
# Epoch 585/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0207
# Epoch 586/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0203
# Epoch 587/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0204
# Epoch 588/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 589/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0212
# Epoch 590/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0215
# Epoch 591/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0213
# Epoch 592/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0208
# Epoch 593/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0205
# Epoch 594/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0205
# Epoch 595/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 596/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0212
# Epoch 597/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0214
# Epoch 598/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0212
# Epoch 599/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 600/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0206
# Epoch 601/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0206
# Epoch 602/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 603/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0212
# Epoch 604/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0213
# Epoch 605/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0211
# Epoch 606/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0209
# Epoch 607/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0207
# Epoch 608/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 609/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0210
# Epoch 610/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0211
# Epoch 611/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0211
# Epoch 612/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0210
# Epoch 613/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0209
# Epoch 614/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 615/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 616/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0210
# Epoch 617/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0211
# Epoch 618/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0210
# Epoch 619/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0209
# Epoch 620/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0209
# Epoch 621/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 622/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0210
# Epoch 623/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0210
# Epoch 624/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0210
# Epoch 625/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0210
# Epoch 626/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0209
# Epoch 627/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0209
# Epoch 628/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0210
# Epoch 629/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0210
# Epoch 630/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0210
# Epoch 631/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0209
# Epoch 632/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 633/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 634/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 635/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 636/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 637/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 638/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 639/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 640/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 641/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 642/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 643/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 644/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 645/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 646/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 647/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 648/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 649/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 650/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 651/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 652/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 653/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 654/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 655/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 656/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 657/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 658/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 659/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 660/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 661/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 662/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 663/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 664/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 665/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 666/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 667/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 668/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 669/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 670/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 671/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 672/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 673/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 674/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 675/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 676/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 677/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 678/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 679/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 680/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 681/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 682/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 683/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 684/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 685/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 686/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 687/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 688/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 689/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0209
# Epoch 690/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0210
# Epoch 691/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0210
# Epoch 692/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0211
# Epoch 693/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0213
# Epoch 694/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0216
# Epoch 695/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0220
# Epoch 696/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0224
# Epoch 697/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0228
# Epoch 698/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0226
# Epoch 699/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0221
# Epoch 700/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0208
# Epoch 701/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0199
# Epoch 702/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0201
# Epoch 703/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0208
# Epoch 704/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0206
# Epoch 705/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0202
# Epoch 706/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0203
# Epoch 707/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 708/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 709/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0206
# Epoch 710/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0205
# Epoch 711/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 712/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0208
# Epoch 713/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 714/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0206
# Epoch 715/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0206
# Epoch 716/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 717/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 718/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 719/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 720/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 721/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 722/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 723/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 724/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 725/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 726/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 727/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 728/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 729/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 730/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 731/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 732/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 733/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 734/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 735/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 736/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 737/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 738/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 739/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 740/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 741/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 742/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 743/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 744/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 745/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 746/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 747/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 748/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 749/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 750/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 751/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 752/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 753/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 754/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 755/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 756/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 757/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 758/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 759/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 760/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 761/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 762/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 763/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 764/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 765/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 766/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 767/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 768/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 769/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 770/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 771/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 772/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 773/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 774/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 775/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 776/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 777/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 778/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 779/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 780/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 781/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 782/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 783/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 784/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 785/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 786/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 787/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 788/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 789/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 790/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 791/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 792/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 793/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 794/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 795/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 796/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 797/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 798/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 799/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 800/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 801/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 802/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 803/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 804/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 805/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 806/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 807/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 808/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 809/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 810/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 811/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 812/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 813/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 814/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 815/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 816/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 817/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 818/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 819/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 820/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 821/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 822/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 823/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 824/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 825/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 826/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 827/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0205
# Epoch 828/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0205
# Epoch 829/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 830/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 831/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 832/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0208
# Epoch 833/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0208
# Epoch 834/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 835/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0204
# Epoch 836/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0200
# Epoch 837/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0197
# Epoch 838/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0198
# Epoch 839/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0209
# Epoch 840/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0229
# Epoch 841/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0222
# Epoch 842/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0228
# Epoch 843/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0237
# Epoch 844/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0235
# Epoch 845/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0229
# Epoch 846/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0227
# Epoch 847/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0212
# Epoch 848/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0200
# Epoch 849/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0203
# Epoch 850/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0211
# Epoch 851/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0202
# Epoch 852/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0201
# Epoch 853/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0205
# Epoch 854/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 855/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0203
# Epoch 856/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0203
# Epoch 857/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0205
# Epoch 858/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0205
# Epoch 859/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0204
# Epoch 860/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0203
# Epoch 861/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0204
# Epoch 862/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0205
# Epoch 863/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0204
# Epoch 864/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0203
# Epoch 865/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0203
# Epoch 866/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0204
# Epoch 867/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0205
# Epoch 868/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0204
# Epoch 869/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0203
# Epoch 870/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0203
# Epoch 871/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0204
# Epoch 872/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0205
# Epoch 873/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0204
# Epoch 874/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0203
# Epoch 875/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0202
# Epoch 876/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0203
# Epoch 877/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0205
# Epoch 878/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 879/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0205
# Epoch 880/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0201
# Epoch 881/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0200
# Epoch 882/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0202
# Epoch 883/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0207
# Epoch 884/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0210
# Epoch 885/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 886/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0200
# Epoch 887/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0198
# Epoch 888/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0203
# Epoch 889/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0212
# Epoch 890/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0211
# Epoch 891/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0202
# Epoch 892/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0197
# Epoch 893/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0202
# Epoch 894/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0213
# Epoch 895/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0211
# Epoch 896/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0200
# Epoch 897/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0198
# Epoch 898/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0205
# Epoch 899/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0213
# Epoch 900/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0206
# Epoch 901/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0199
# Epoch 902/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0200
# Epoch 903/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0209
# Epoch 904/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0210
# Epoch 905/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0201
# Epoch 906/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0199
# Epoch 907/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0204
# Epoch 908/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0211
# Epoch 909/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 910/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0199
# Epoch 911/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0200
# Epoch 912/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0207
# Epoch 913/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0209
# Epoch 914/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0202
# Epoch 915/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0199
# Epoch 916/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0202
# Epoch 917/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0209
# Epoch 918/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 919/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0200
# Epoch 920/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0199
# Epoch 921/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0205
# Epoch 922/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0209
# Epoch 923/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0204
# Epoch 924/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0199
# Epoch 925/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0200
# Epoch 926/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0207
# Epoch 927/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0209
# Epoch 928/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0203
# Epoch 929/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0199
# Epoch 930/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0201
# Epoch 931/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0208
# Epoch 932/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0208
# Epoch 933/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0201
# Epoch 934/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0199
# Epoch 935/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0203
# Epoch 936/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0209
# Epoch 937/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 938/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0200
# Epoch 939/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0199
# Epoch 940/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0205
# Epoch 941/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0210
# Epoch 942/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0204
# Epoch 943/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0199
# Epoch 944/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0200
# Epoch 945/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0207
# Epoch 946/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0209
# Epoch 947/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0202
# Epoch 948/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0199
# Epoch 949/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0202
# Epoch 950/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0208
# Epoch 951/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 952/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0201
# Epoch 953/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0199
# Epoch 954/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0203
# Epoch 955/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0209
# Epoch 956/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0205
# Epoch 957/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0200
# Epoch 958/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0200
# Epoch 959/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0205
# Epoch 960/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0209
# Epoch 961/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0204
# Epoch 962/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0199
# Epoch 963/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0200
# Epoch 964/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0207
# Epoch 965/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0208
# Epoch 966/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0202
# Epoch 967/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0199
# Epoch 968/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0202
# Epoch 969/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0208
# Epoch 970/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 971/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0201
# Epoch 972/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0199
# Epoch 973/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0203
# Epoch 974/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0208
# Epoch 975/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0205
# Epoch 976/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0200
# Epoch 977/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0200
# Epoch 978/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0205
# Epoch 979/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0208
# Epoch 980/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0204
# Epoch 981/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0200
# Epoch 982/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0200
# Epoch 983/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0206
# Epoch 984/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0208
# Epoch 985/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0203
# Epoch 986/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0200
# Epoch 987/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0201
# Epoch 988/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0207
# Epoch 989/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0207
# Epoch 990/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0202
# Epoch 991/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0200
# Epoch 992/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0202
# Epoch 993/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0208
# Epoch 994/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 995/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0201
# Epoch 996/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0200
# Epoch 997/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0203
# Epoch 998/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0208
# Epoch 999/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0206
# Epoch 1000/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0201
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 150)               600
# _________________________________________________________________
# dense_8 (Dense)              (None, 150)               22650
# _________________________________________________________________
# dense_9 (Dense)              (None, 150)               22650
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 46,051
# Trainable params: 46,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
fan_force150_real1,fan_force150_pre1 = FanGuiHua_force1(valid50_y_Force1,N_pre50_Y_Force1)

np.savetxt('force1500_步长10_混合注意力.csv',np.hstack((fan_force150_real1,fan_force150_pre1)),delimiter=',')

# %%
# 输入50步长输出1步长Force2
force250_scaled1 = deal_data2(np.hstack((Heave,Surge,Pitch,Force2))[3500:,:], 4, 509)
force250_x1,force250_y1 = split_sequence(force250_scaled1, 500)
# print(force150_x1.shape)
# 输入100步长输出1步长
# force1100_scaled1 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[300:,:], 4, 100)
# force1100_x1,force1100_y1 = split_sequence(force1100_scaled1, 100)
# print(force1100_x1.shape)

# %%
train_force250_x1, train_force250_y1, valid_force250_x1, valid_force250_y1 = split_train_valid(force250_x1,force250_y1, 4500, 7500, 12000)
train50_x_Force2, valid50_x_Force2 = np.hstack((pretrain_heave50_Y1, pretrain_surge50_Y1, pretrain_pitch50_Y1)), np.hstack((pre_heave50_Y1, pre_surge50_Y1, pre_pitch50_Y1))
train50_y_Force2, valid50_y_Force2 = train_force250_y1, valid_force250_y1

# %%
N_model50_Force2, N_history50_Force2, N_pre50_train_Y_Force2, N_pre50_Y_Force2 = Model_NN(train50_x_Force2, train50_y_Force2, valid50_x_Force2, valid50_y_Force2, lr=0.01, epochs=1000, batch_size=256)
# Out:
# Train on 3000 samples, validate on 4500 samples
# Epoch 1/1000
#  - 0s - loss: 0.0520 - val_loss: 0.0261
# Epoch 2/1000
#  - 0s - loss: 0.0157 - val_loss: 0.0192
# Epoch 3/1000
#  - 0s - loss: 0.0077 - val_loss: 0.0186
# Epoch 4/1000
#  - 0s - loss: 0.0064 - val_loss: 0.0174
# Epoch 5/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0179
# Epoch 6/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0181
# Epoch 7/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0178
# Epoch 8/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0178
# Epoch 9/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0178
# Epoch 10/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0179
# Epoch 11/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0178
# Epoch 12/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0179
# Epoch 13/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0179
# Epoch 14/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0179
# Epoch 15/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0179
# Epoch 16/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0179
# Epoch 17/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0179
# Epoch 18/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0180
# Epoch 19/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0180
# Epoch 20/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0180
# Epoch 21/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0180
# Epoch 22/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0180
# Epoch 23/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0180
# Epoch 24/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0181
# Epoch 25/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0181
# Epoch 26/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0181
# Epoch 27/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0181
# Epoch 28/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0181
# Epoch 29/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0181
# Epoch 30/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0181
# Epoch 31/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0181
# Epoch 32/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0182
# Epoch 33/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0182
# Epoch 34/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0182
# Epoch 35/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0182
# Epoch 36/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0182
# Epoch 37/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0182
# Epoch 38/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0182
# Epoch 39/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0183
# Epoch 40/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0183
# Epoch 41/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0183
# Epoch 42/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0184
# Epoch 43/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0184
# Epoch 44/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0185
# Epoch 45/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0185
# Epoch 46/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0186
# Epoch 47/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0188
# Epoch 48/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0190
# Epoch 49/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0192
# Epoch 50/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0195
# Epoch 51/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0198
# Epoch 52/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0201
# Epoch 53/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0199
# Epoch 54/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0192
# Epoch 55/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0182
# Epoch 56/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0172
# Epoch 57/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0164
# Epoch 58/1000
#  - 0s - loss: 0.0064 - val_loss: 0.0158
# Epoch 59/1000
#  - 0s - loss: 0.0066 - val_loss: 0.0158
# Epoch 60/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0176
# Epoch 61/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0186
# Epoch 62/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0178
# Epoch 63/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0177
# Epoch 64/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0177
# Epoch 65/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0176
# Epoch 66/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0176
# Epoch 67/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0176
# Epoch 68/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0175
# Epoch 69/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0174
# Epoch 70/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0172
# Epoch 71/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0168
# Epoch 72/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0160
# Epoch 73/1000
#  - 0s - loss: 0.0065 - val_loss: 0.0153
# Epoch 74/1000
#  - 0s - loss: 0.0073 - val_loss: 0.0153
# Epoch 75/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0193
# Epoch 76/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0190
# Epoch 77/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0172
# Epoch 78/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0181
# Epoch 79/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0180
# Epoch 80/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0179
# Epoch 81/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0181
# Epoch 82/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0181
# Epoch 83/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0183
# Epoch 84/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0185
# Epoch 85/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0189
# Epoch 86/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0198
# Epoch 87/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0213
# Epoch 88/1000
#  - 0s - loss: 0.0067 - val_loss: 0.0225
# Epoch 89/1000
#  - 0s - loss: 0.0071 - val_loss: 0.0201
# Epoch 90/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0172
# Epoch 91/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0168
# Epoch 92/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0179
# Epoch 93/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0177
# Epoch 94/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0172
# Epoch 95/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0171
# Epoch 96/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0170
# Epoch 97/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0168
# Epoch 98/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0168
# Epoch 99/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0168
# Epoch 100/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0169
# Epoch 101/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0171
# Epoch 102/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0171
# Epoch 103/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0172
# Epoch 104/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0171
# Epoch 105/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0171
# Epoch 106/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0170
# Epoch 107/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0168
# Epoch 108/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0164
# Epoch 109/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0160
# Epoch 110/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0158
# Epoch 111/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0162
# Epoch 112/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0177
# Epoch 113/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0197
# Epoch 114/1000
#  - 0s - loss: 0.0065 - val_loss: 0.0223
# Epoch 115/1000
#  - 0s - loss: 0.0077 - val_loss: 0.0214
# Epoch 116/1000
#  - 0s - loss: 0.0068 - val_loss: 0.0173
# Epoch 117/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0169
# Epoch 118/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0184
# Epoch 119/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0176
# Epoch 120/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0173
# Epoch 121/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0175
# Epoch 122/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0175
# Epoch 123/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0174
# Epoch 124/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0174
# Epoch 125/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0174
# Epoch 126/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0175
# Epoch 127/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0178
# Epoch 128/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0185
# Epoch 129/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0200
# Epoch 130/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0224
# Epoch 131/1000
#  - 0s - loss: 0.0072 - val_loss: 0.0212
# Epoch 132/1000
#  - 0s - loss: 0.0065 - val_loss: 0.0171
# Epoch 133/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0167
# Epoch 134/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0182
# Epoch 135/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0174
# Epoch 136/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0169
# Epoch 137/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0172
# Epoch 138/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0172
# Epoch 139/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0171
# Epoch 140/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0171
# Epoch 141/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0171
# Epoch 142/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0173
# Epoch 143/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0175
# Epoch 144/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0178
# Epoch 145/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0183
# Epoch 146/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0188
# Epoch 147/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0192
# Epoch 148/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0189
# Epoch 149/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0179
# Epoch 150/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0169
# Epoch 151/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0163
# Epoch 152/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0165
# Epoch 153/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0172
# Epoch 154/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0177
# Epoch 155/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0181
# Epoch 156/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0183
# Epoch 157/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0182
# Epoch 158/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0178
# Epoch 159/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0172
# Epoch 160/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0166
# Epoch 161/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0165
# Epoch 162/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0167
# Epoch 163/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0173
# Epoch 164/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0180
# Epoch 165/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0187
# Epoch 166/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0191
# Epoch 167/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0188
# Epoch 168/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0177
# Epoch 169/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0167
# Epoch 170/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0162
# Epoch 171/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0165
# Epoch 172/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0173
# Epoch 173/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0178
# Epoch 174/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0181
# Epoch 175/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0180
# Epoch 176/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0176
# Epoch 177/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0170
# Epoch 178/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0165
# Epoch 179/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0165
# Epoch 180/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0169
# Epoch 181/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0175
# Epoch 182/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0181
# Epoch 183/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0184
# Epoch 184/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0184
# Epoch 185/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0178
# Epoch 186/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0169
# Epoch 187/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0163
# Epoch 188/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0164
# Epoch 189/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0170
# Epoch 190/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0177
# Epoch 191/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0181
# Epoch 192/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0183
# Epoch 193/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0179
# Epoch 194/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0171
# Epoch 195/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0165
# Epoch 196/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0163
# Epoch 197/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0168
# Epoch 198/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0175
# Epoch 199/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0180
# Epoch 200/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0182
# Epoch 201/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0180
# Epoch 202/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0173
# Epoch 203/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0166
# Epoch 204/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0163
# Epoch 205/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0167
# Epoch 206/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0174
# Epoch 207/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0179
# Epoch 208/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0182
# Epoch 209/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0179
# Epoch 210/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0173
# Epoch 211/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0165
# Epoch 212/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0163
# Epoch 213/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0167
# Epoch 214/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0174
# Epoch 215/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0179
# Epoch 216/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0181
# Epoch 217/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0178
# Epoch 218/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0171
# Epoch 219/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0164
# Epoch 220/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0163
# Epoch 221/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0168
# Epoch 222/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0175
# Epoch 223/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0179
# Epoch 224/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0180
# Epoch 225/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0176
# Epoch 226/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0169
# Epoch 227/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0163
# Epoch 228/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0164
# Epoch 229/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0171
# Epoch 230/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0177
# Epoch 231/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0180
# Epoch 232/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0179
# Epoch 233/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0173
# Epoch 234/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0165
# Epoch 235/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0163
# Epoch 236/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0167
# Epoch 237/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0174
# Epoch 238/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0178
# Epoch 239/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0180
# Epoch 240/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0176
# Epoch 241/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0168
# Epoch 242/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0163
# Epoch 243/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0165
# Epoch 244/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0171
# Epoch 245/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0177
# Epoch 246/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0179
# Epoch 247/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0177
# Epoch 248/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0171
# Epoch 249/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0164
# Epoch 250/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0163
# Epoch 251/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0169
# Epoch 252/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0175
# Epoch 253/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0179
# Epoch 254/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0178
# Epoch 255/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0172
# Epoch 256/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0165
# Epoch 257/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0163
# Epoch 258/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0168
# Epoch 259/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0174
# Epoch 260/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0178
# Epoch 261/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0178
# Epoch 262/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0173
# Epoch 263/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0166
# Epoch 264/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0163
# Epoch 265/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0167
# Epoch 266/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0174
# Epoch 267/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0177
# Epoch 268/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0178
# Epoch 269/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0173
# Epoch 270/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0166
# Epoch 271/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0163
# Epoch 272/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0167
# Epoch 273/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0173
# Epoch 274/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0177
# Epoch 275/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0178
# Epoch 276/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0173
# Epoch 277/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0166
# Epoch 278/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0163
# Epoch 279/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0167
# Epoch 280/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0173
# Epoch 281/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0177
# Epoch 282/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0177
# Epoch 283/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0172
# Epoch 284/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0165
# Epoch 285/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0163
# Epoch 286/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0168
# Epoch 287/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0174
# Epoch 288/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0177
# Epoch 289/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0176
# Epoch 290/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0171
# Epoch 291/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0164
# Epoch 292/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0163
# Epoch 293/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0169
# Epoch 294/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0174
# Epoch 295/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0177
# Epoch 296/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0175
# Epoch 297/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0169
# Epoch 298/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0163
# Epoch 299/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0164
# Epoch 300/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0170
# Epoch 301/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0175
# Epoch 302/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0176
# Epoch 303/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0174
# Epoch 304/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0167
# Epoch 305/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0162
# Epoch 306/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0165
# Epoch 307/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0172
# Epoch 308/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0175
# Epoch 309/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0175
# Epoch 310/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0172
# Epoch 311/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0165
# Epoch 312/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0162
# Epoch 313/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0167
# Epoch 314/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0173
# Epoch 315/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0174
# Epoch 316/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0174
# Epoch 317/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0169
# Epoch 318/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0163
# Epoch 319/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0163
# Epoch 320/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0169
# Epoch 321/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0173
# Epoch 322/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0173
# Epoch 323/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0171
# Epoch 324/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0166
# Epoch 325/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0162
# Epoch 326/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0164
# Epoch 327/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0170
# Epoch 328/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0172
# Epoch 329/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0170
# Epoch 330/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0166
# Epoch 331/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0162
# Epoch 332/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0161
# Epoch 333/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0165
# Epoch 334/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0169
# Epoch 335/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0169
# Epoch 336/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0166
# Epoch 337/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0164
# Epoch 338/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0163
# Epoch 339/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0164
# Epoch 340/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0165
# Epoch 341/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0165
# Epoch 342/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0166
# Epoch 343/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0174
# Epoch 344/1000
#  - 0s - loss: 0.0068 - val_loss: 0.0184
# Epoch 345/1000
#  - 0s - loss: 0.0064 - val_loss: 0.0186
# Epoch 346/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0163
# Epoch 347/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0163
# Epoch 348/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0169
# Epoch 349/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0183
# Epoch 350/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0169
# Epoch 351/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0155
# Epoch 352/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0153
# Epoch 353/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0164
# Epoch 354/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0168
# Epoch 355/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0166
# Epoch 356/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0166
# Epoch 357/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0175
# Epoch 358/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0178
# Epoch 359/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0170
# Epoch 360/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0159
# Epoch 361/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0154
# Epoch 362/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0159
# Epoch 363/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0170
# Epoch 364/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0169
# Epoch 365/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0165
# Epoch 366/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0179
# Epoch 367/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0190
# Epoch 368/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0174
# Epoch 369/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0163
# Epoch 370/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0155
# Epoch 371/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0161
# Epoch 372/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0170
# Epoch 373/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0173
# Epoch 374/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0167
# Epoch 375/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0162
# Epoch 376/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0162
# Epoch 377/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0164
# Epoch 378/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0163
# Epoch 379/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0167
# Epoch 380/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0176
# Epoch 381/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0169
# Epoch 382/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0159
# Epoch 383/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0161
# Epoch 384/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0165
# Epoch 385/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0164
# Epoch 386/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0164
# Epoch 387/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0177
# Epoch 388/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0174
# Epoch 389/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0157
# Epoch 390/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0158
# Epoch 391/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0166
# Epoch 392/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0164
# Epoch 393/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0163
# Epoch 394/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0176
# Epoch 395/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0172
# Epoch 396/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0156
# Epoch 397/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0158
# Epoch 398/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0165
# Epoch 399/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0163
# Epoch 400/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0164
# Epoch 401/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0173
# Epoch 402/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0167
# Epoch 403/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0155
# Epoch 404/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0159
# Epoch 405/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0163
# Epoch 406/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0162
# Epoch 407/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0165
# Epoch 408/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0171
# Epoch 409/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0163
# Epoch 410/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0157
# Epoch 411/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0159
# Epoch 412/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0161
# Epoch 413/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0162
# Epoch 414/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0166
# Epoch 415/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0168
# Epoch 416/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0161
# Epoch 417/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0158
# Epoch 418/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0158
# Epoch 419/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0160
# Epoch 420/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0163
# Epoch 421/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0168
# Epoch 422/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0165
# Epoch 423/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0159
# Epoch 424/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0156
# Epoch 425/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0158
# Epoch 426/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0160
# Epoch 427/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0164
# Epoch 428/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0167
# Epoch 429/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0162
# Epoch 430/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0157
# Epoch 431/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0156
# Epoch 432/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0158
# Epoch 433/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0161
# Epoch 434/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0165
# Epoch 435/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0165
# Epoch 436/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0160
# Epoch 437/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0156
# Epoch 438/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0156
# Epoch 439/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0158
# Epoch 440/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0162
# Epoch 441/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0165
# Epoch 442/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0163
# Epoch 443/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0158
# Epoch 444/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0155
# Epoch 445/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0156
# Epoch 446/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0159
# Epoch 447/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0162
# Epoch 448/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0164
# Epoch 449/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0161
# Epoch 450/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0156
# Epoch 451/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0154
# Epoch 452/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0156
# Epoch 453/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0159
# Epoch 454/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0162
# Epoch 455/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0163
# Epoch 456/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0159
# Epoch 457/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0155
# Epoch 458/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0154
# Epoch 459/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0155
# Epoch 460/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0159
# Epoch 461/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0162
# Epoch 462/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0161
# Epoch 463/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0157
# Epoch 464/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0154
# Epoch 465/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0153
# Epoch 466/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0155
# Epoch 467/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0158
# Epoch 468/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0161
# Epoch 469/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0160
# Epoch 470/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0156
# Epoch 471/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0152
# Epoch 472/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0152
# Epoch 473/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0154
# Epoch 474/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0157
# Epoch 475/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0161
# Epoch 476/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0160
# Epoch 477/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0155
# Epoch 478/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0151
# Epoch 479/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0151
# Epoch 480/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0152
# Epoch 481/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0156
# Epoch 482/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0161
# Epoch 483/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0160
# Epoch 484/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0155
# Epoch 485/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0151
# Epoch 486/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0150
# Epoch 487/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0151
# Epoch 488/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0154
# Epoch 489/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0161
# Epoch 490/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0160
# Epoch 491/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0155
# Epoch 492/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0151
# Epoch 493/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0149
# Epoch 494/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0150
# Epoch 495/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0153
# Epoch 496/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0159
# Epoch 497/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0159
# Epoch 498/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0155
# Epoch 499/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0151
# Epoch 500/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0150
# Epoch 501/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0150
# Epoch 502/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0152
# Epoch 503/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0158
# Epoch 504/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0159
# Epoch 505/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0156
# Epoch 506/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0153
# Epoch 507/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0150
# Epoch 508/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0148
# Epoch 509/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0152
# Epoch 510/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0160
# Epoch 511/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0162
# Epoch 512/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0156
# Epoch 513/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0149
# Epoch 514/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0145
# Epoch 515/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0147
# Epoch 516/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0157
# Epoch 517/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0163
# Epoch 518/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0156
# Epoch 519/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0148
# Epoch 520/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0145
# Epoch 521/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0148
# Epoch 522/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0155
# Epoch 523/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0157
# Epoch 524/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0153
# Epoch 525/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0150
# Epoch 526/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0150
# Epoch 527/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0151
# Epoch 528/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0152
# Epoch 529/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0151
# Epoch 530/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0150
# Epoch 531/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0155
# Epoch 532/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0158
# Epoch 533/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0157
# Epoch 534/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0152
# Epoch 535/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0147
# Epoch 536/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0149
# Epoch 537/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0158
# Epoch 538/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0162
# Epoch 539/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0156
# Epoch 540/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0147
# Epoch 541/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0144
# Epoch 542/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0151
# Epoch 543/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0162
# Epoch 544/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0160
# Epoch 545/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0151
# Epoch 546/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0145
# Epoch 547/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0147
# Epoch 548/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0157
# Epoch 549/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0160
# Epoch 550/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0153
# Epoch 551/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0147
# Epoch 552/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0146
# Epoch 553/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0151
# Epoch 554/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0156
# Epoch 555/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0154
# Epoch 556/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0151
# Epoch 557/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0150
# Epoch 558/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0150
# Epoch 559/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0151
# Epoch 560/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0151
# Epoch 561/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0152
# Epoch 562/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0154
# Epoch 563/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0154
# Epoch 564/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0152
# Epoch 565/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0148
# Epoch 566/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0147
# Epoch 567/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0152
# Epoch 568/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0157
# Epoch 569/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0157
# Epoch 570/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0153
# Epoch 571/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0147
# Epoch 572/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0146
# Epoch 573/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0154
# Epoch 574/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0160
# Epoch 575/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0159
# Epoch 576/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0152
# Epoch 577/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0145
# Epoch 578/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0147
# Epoch 579/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0156
# Epoch 580/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0160
# Epoch 581/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0156
# Epoch 582/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0148
# Epoch 583/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0145
# Epoch 584/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0151
# Epoch 585/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0159
# Epoch 586/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0159
# Epoch 587/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0152
# Epoch 588/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0145
# Epoch 589/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0147
# Epoch 590/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0156
# Epoch 591/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0160
# Epoch 592/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0156
# Epoch 593/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0148
# Epoch 594/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0145
# Epoch 595/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0152
# Epoch 596/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0159
# Epoch 597/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0159
# Epoch 598/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0152
# Epoch 599/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0146
# Epoch 600/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0148
# Epoch 601/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0156
# Epoch 602/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0159
# Epoch 603/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0156
# Epoch 604/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0149
# Epoch 605/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0146
# Epoch 606/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0152
# Epoch 607/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0159
# Epoch 608/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0158
# Epoch 609/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0153
# Epoch 610/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0147
# Epoch 611/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0149
# Epoch 612/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0155
# Epoch 613/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0158
# Epoch 614/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0155
# Epoch 615/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0149
# Epoch 616/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0146
# Epoch 617/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0152
# Epoch 618/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0158
# Epoch 619/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0158
# Epoch 620/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0152
# Epoch 621/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0146
# Epoch 622/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0149
# Epoch 623/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0157
# Epoch 624/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0160
# Epoch 625/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0156
# Epoch 626/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0147
# Epoch 627/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0146
# Epoch 628/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0153
# Epoch 629/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0160
# Epoch 630/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0159
# Epoch 631/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0151
# Epoch 632/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0145
# Epoch 633/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0150
# Epoch 634/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0159
# Epoch 635/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0160
# Epoch 636/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0154
# Epoch 637/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0146
# Epoch 638/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0148
# Epoch 639/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0156
# Epoch 640/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0160
# Epoch 641/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0156
# Epoch 642/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0148
# Epoch 643/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0146
# Epoch 644/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0154
# Epoch 645/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0160
# Epoch 646/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0157
# Epoch 647/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0151
# Epoch 648/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0146
# Epoch 649/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0151
# Epoch 650/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0158
# Epoch 651/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0159
# Epoch 652/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0154
# Epoch 653/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0148
# Epoch 654/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0149
# Epoch 655/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0154
# Epoch 656/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0158
# Epoch 657/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0157
# Epoch 658/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0153
# Epoch 659/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0147
# Epoch 660/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0150
# Epoch 661/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0156
# Epoch 662/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0158
# Epoch 663/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0155
# Epoch 664/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0149
# Epoch 665/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0147
# Epoch 666/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0153
# Epoch 667/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0158
# Epoch 668/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0157
# Epoch 669/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0150
# Epoch 670/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0146
# Epoch 671/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0152
# Epoch 672/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0160
# Epoch 673/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0160
# Epoch 674/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0152
# Epoch 675/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0145
# Epoch 676/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0150
# Epoch 677/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0160
# Epoch 678/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0162
# Epoch 679/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0155
# Epoch 680/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0147
# Epoch 681/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0149
# Epoch 682/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0157
# Epoch 683/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0161
# Epoch 684/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0157
# Epoch 685/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0149
# Epoch 686/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0148
# Epoch 687/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0155
# Epoch 688/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0160
# Epoch 689/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0157
# Epoch 690/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0150
# Epoch 691/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0147
# Epoch 692/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0154
# Epoch 693/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0160
# Epoch 694/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0158
# Epoch 695/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0151
# Epoch 696/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0147
# Epoch 697/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0154
# Epoch 698/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0160
# Epoch 699/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0159
# Epoch 700/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0152
# Epoch 701/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0147
# Epoch 702/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0152
# Epoch 703/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0160
# Epoch 704/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0159
# Epoch 705/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0152
# Epoch 706/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0147
# Epoch 707/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0153
# Epoch 708/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0160
# Epoch 709/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0160
# Epoch 710/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0153
# Epoch 711/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0147
# Epoch 712/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0153
# Epoch 713/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0161
# Epoch 714/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0160
# Epoch 715/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0152
# Epoch 716/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0147
# Epoch 717/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0154
# Epoch 718/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0161
# Epoch 719/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0160
# Epoch 720/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0151
# Epoch 721/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0147
# Epoch 722/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0155
# Epoch 723/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0162
# Epoch 724/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0158
# Epoch 725/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0149
# Epoch 726/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0147
# Epoch 727/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0159
# Epoch 728/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0164
# Epoch 729/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0158
# Epoch 730/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0147
# Epoch 731/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0152
# Epoch 732/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0157
# Epoch 733/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0160
# Epoch 734/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0152
# Epoch 735/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0152
# Epoch 736/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0151
# Epoch 737/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0157
# Epoch 738/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0155
# Epoch 739/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0154
# Epoch 740/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0151
# Epoch 741/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0153
# Epoch 742/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0153
# Epoch 743/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0156
# Epoch 744/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0155
# Epoch 745/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0154
# Epoch 746/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0148
# Epoch 747/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0150
# Epoch 748/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0157
# Epoch 749/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0165
# Epoch 750/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0160
# Epoch 751/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0148
# Epoch 752/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0141
# Epoch 753/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0163
# Epoch 754/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0178
# Epoch 755/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0169
# Epoch 756/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0150
# Epoch 757/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0151
# Epoch 758/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0158
# Epoch 759/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0160
# Epoch 760/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0157
# Epoch 761/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0151
# Epoch 762/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0160
# Epoch 763/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0156
# Epoch 764/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0155
# Epoch 765/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0154
# Epoch 766/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0156
# Epoch 767/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0154
# Epoch 768/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0157
# Epoch 769/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0154
# Epoch 770/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0154
# Epoch 771/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0154
# Epoch 772/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0156
# Epoch 773/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0155
# Epoch 774/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0153
# Epoch 775/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0153
# Epoch 776/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0155
# Epoch 777/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0156
# Epoch 778/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0155
# Epoch 779/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0153
# Epoch 780/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0153
# Epoch 781/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0155
# Epoch 782/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0156
# Epoch 783/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0155
# Epoch 784/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0152
# Epoch 785/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0152
# Epoch 786/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0155
# Epoch 787/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0158
# Epoch 788/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0157
# Epoch 789/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0152
# Epoch 790/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0148
# Epoch 791/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0153
# Epoch 792/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0162
# Epoch 793/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0164
# Epoch 794/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0155
# Epoch 795/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0144
# Epoch 796/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0147
# Epoch 797/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0167
# Epoch 798/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0174
# Epoch 799/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0158
# Epoch 800/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0144
# Epoch 801/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0155
# Epoch 802/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0172
# Epoch 803/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0162
# Epoch 804/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0149
# Epoch 805/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0156
# Epoch 806/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0167
# Epoch 807/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0157
# Epoch 808/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0150
# Epoch 809/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0157
# Epoch 810/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0162
# Epoch 811/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0155
# Epoch 812/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0152
# Epoch 813/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0156
# Epoch 814/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0160
# Epoch 815/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0157
# Epoch 816/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0153
# Epoch 817/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0153
# Epoch 818/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0159
# Epoch 819/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0160
# Epoch 820/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0156
# Epoch 821/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0150
# Epoch 822/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0153
# Epoch 823/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0162
# Epoch 824/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0164
# Epoch 825/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0155
# Epoch 826/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0147
# Epoch 827/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0153
# Epoch 828/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0168
# Epoch 829/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0168
# Epoch 830/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0154
# Epoch 831/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0145
# Epoch 832/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0162
# Epoch 833/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0171
# Epoch 834/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0160
# Epoch 835/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0147
# Epoch 836/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0158
# Epoch 837/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0168
# Epoch 838/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0161
# Epoch 839/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0150
# Epoch 840/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0154
# Epoch 841/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0167
# Epoch 842/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0162
# Epoch 843/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0152
# Epoch 844/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0151
# Epoch 845/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0167
# Epoch 846/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0164
# Epoch 847/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0153
# Epoch 848/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0150
# Epoch 849/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0166
# Epoch 850/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0165
# Epoch 851/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0154
# Epoch 852/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0149
# Epoch 853/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0165
# Epoch 854/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0165
# Epoch 855/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0156
# Epoch 856/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0149
# Epoch 857/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0163
# Epoch 858/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0165
# Epoch 859/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0158
# Epoch 860/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0150
# Epoch 861/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0158
# Epoch 862/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0166
# Epoch 863/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0162
# Epoch 864/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0152
# Epoch 865/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0152
# Epoch 866/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0166
# Epoch 867/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0167
# Epoch 868/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0156
# Epoch 869/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0148
# Epoch 870/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0162
# Epoch 871/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0169
# Epoch 872/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0160
# Epoch 873/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0150
# Epoch 874/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0156
# Epoch 875/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0168
# Epoch 876/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0165
# Epoch 877/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0153
# Epoch 878/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0150
# Epoch 879/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0168
# Epoch 880/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0169
# Epoch 881/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0156
# Epoch 882/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0149
# Epoch 883/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0165
# Epoch 884/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0168
# Epoch 885/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0157
# Epoch 886/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0150
# Epoch 887/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0163
# Epoch 888/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0167
# Epoch 889/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0158
# Epoch 890/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0151
# Epoch 891/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0159
# Epoch 892/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0167
# Epoch 893/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0162
# Epoch 894/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0153
# Epoch 895/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0153
# Epoch 896/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0166
# Epoch 897/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0168
# Epoch 898/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0157
# Epoch 899/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0150
# Epoch 900/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0160
# Epoch 901/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0169
# Epoch 902/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0164
# Epoch 903/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0153
# Epoch 904/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0152
# Epoch 905/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0167
# Epoch 906/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0170
# Epoch 907/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0159
# Epoch 908/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0150
# Epoch 909/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0159
# Epoch 910/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0169
# Epoch 911/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0165
# Epoch 912/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0154
# Epoch 913/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0152
# Epoch 914/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0166
# Epoch 915/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0170
# Epoch 916/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0160
# Epoch 917/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0150
# Epoch 918/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0158
# Epoch 919/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0165
# Epoch 920/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0165
# Epoch 921/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0157
# Epoch 922/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0153
# Epoch 923/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0159
# Epoch 924/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0167
# Epoch 925/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0165
# Epoch 926/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0158
# Epoch 927/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0153
# Epoch 928/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0159
# Epoch 929/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0167
# Epoch 930/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0167
# Epoch 931/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0160
# Epoch 932/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0153
# Epoch 933/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0155
# Epoch 934/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0166
# Epoch 935/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0170
# Epoch 936/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0165
# Epoch 937/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0156
# Epoch 938/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0152
# Epoch 939/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0161
# Epoch 940/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0169
# Epoch 941/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0167
# Epoch 942/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0160
# Epoch 943/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0153
# Epoch 944/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0155
# Epoch 945/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0164
# Epoch 946/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0168
# Epoch 947/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0166
# Epoch 948/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0161
# Epoch 949/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0154
# Epoch 950/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0155
# Epoch 951/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0161
# Epoch 952/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0167
# Epoch 953/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0169
# Epoch 954/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0166
# Epoch 955/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0160
# Epoch 956/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0154
# Epoch 957/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0153
# Epoch 958/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0157
# Epoch 959/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0162
# Epoch 960/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0165
# Epoch 961/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0169
# Epoch 962/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0172
# Epoch 963/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0172
# Epoch 964/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0164
# Epoch 965/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0153
# Epoch 966/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0150
# Epoch 967/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0157
# Epoch 968/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0163
# Epoch 969/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0168
# Epoch 970/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0169
# Epoch 971/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0170
# Epoch 972/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0163
# Epoch 973/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0154
# Epoch 974/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0154
# Epoch 975/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0163
# Epoch 976/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0168
# Epoch 977/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0169
# Epoch 978/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0166
# Epoch 979/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0160
# Epoch 980/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0155
# Epoch 981/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0158
# Epoch 982/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0164
# Epoch 983/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0168
# Epoch 984/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0170
# Epoch 985/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0169
# Epoch 986/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0162
# Epoch 987/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0155
# Epoch 988/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0154
# Epoch 989/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0161
# Epoch 990/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0168
# Epoch 991/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0173
# Epoch 992/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0173
# Epoch 993/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0169
# Epoch 994/1000
#  - 0s - loss: 0.0038 - val_loss: 0.0159
# Epoch 995/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0152
# Epoch 996/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0156
# Epoch 997/1000
#  - 0s - loss: 0.0039 - val_loss: 0.0159
# Epoch 998/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0162
# Epoch 999/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0163
# Epoch 1000/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0168
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 150)               600
# _________________________________________________________________
# dense_12 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_13 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 46,051
# Trainable params: 46,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
fan_force250_real1,fan_force250_pre1 = FanGuiHua_force2(valid50_y_Force2,N_pre50_Y_Force2)

np.savetxt('force2500_步长10_混合注意力.csv',np.hstack((fan_force250_real1,fan_force250_pre1)),delimiter=',')

# %%
RNSE(valid50_y_Force1,N_pre50_Y_Force1)
Acc(valid50_y_Force1,N_pre50_Y_Force1)
# Out:
# RMSE(sklearn): 0.14163581024032532
# Acc: 0.8804074143209842

# %%
RNSE(valid50_y_Force2,N_pre50_Y_Force2)
Acc(valid50_y_Force2,N_pre50_Y_Force2)
# Out:
# RMSE(sklearn): 0.12977153551636358
# Acc: 0.8921974904885767
