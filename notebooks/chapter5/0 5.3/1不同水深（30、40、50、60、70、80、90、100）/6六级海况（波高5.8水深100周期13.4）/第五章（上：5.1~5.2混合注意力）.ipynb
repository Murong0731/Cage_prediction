# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
from math import sqrt
from numpy import concatenate
from pandas import read_csv, DataFrame, concat
from datetime import datetime
from sklearn.metrics import mean_squared_error

from sklearn.preprocessing import MinMaxScaler, StandardScaler

import keras.backend as K
from keras.layers import Multiply
from keras.models import Sequential ,Model
from keras.layers import Dense , Input , Reshape , Flatten ,Permute , Lambda , RepeatVector ,Conv1D , MaxPooling1D , Dropout, Bidirectional, Activation
from keras.layers import GRU, LSTM
from keras.utils.vis_utils import plot_model
from keras.optimizers import SGD,Adam
from keras.utils import np_utils   #np_utils
from keras.callbacks import TensorBoard  #TensorBoard可视化
# Out:
# Using TensorFlow backend.

# %%
# T:0
# H:1
# Surge:2
# Heave:4
# Force1:8
# 四级海况（波高2周期11.2水深50)
data_1 = pd.read_csv('100水深.csv')
data_1.head()
# Out:
#      T      H  Surge     Sway  Heave          Roll     Pitch           Yaw  \
# 0  0.1  453.0   1.88 -0.00113  127.0  5.540000e-08  0.001010 -1.250000e-09
# 1  0.2  445.0   6.80  0.02010  337.0 -5.460000e-07  0.002720  3.060000e-07
# 2  0.3  438.0  13.00  0.03050  526.0 -5.330000e-07  0.002420  2.260000e-06
# 3  0.4  432.0  19.70  0.03280  613.0  4.600000e-06 -0.000061  5.650000e-06
# 4  0.5  429.0  27.00  0.06520  586.0 -5.470000e-06 -0.000520  8.320000e-06
#
#    Force1  Force2
# 0  5160.0  5130.0
# 1  5440.0  5350.0
# 2  5680.0  5560.0
# 3  5790.0  5650.0
# 4  5780.0  5600.0

# %%
data_1.describe()
# Out:
#                   T             H         Surge          Sway         Heave  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean    2000.050030     -0.234364     42.740794      0.005547    -29.970599
# std     1154.714989   1063.769171    334.425798      2.583934   1018.223612
# min        0.100000  -4340.000000  -1990.000000    -12.100000  -4250.000000
# 25%     1000.075015   -709.000000   -151.000000     -1.630000   -710.000000
# 50%     2000.050030     -6.315000     24.300000     -0.002000    -38.000000
# 75%     3000.025045    715.250000    223.000000      1.660000    658.000000
# max     4000.000060   3610.000000   1630.000000     17.800000   3440.000000
#
#                Roll         Pitch           Yaw        Force1        Force2
# count  4.000000e+04  40000.000000  40000.000000  40000.000000  40000.000000
# mean   5.178942e-07     -0.000508      0.000011   5140.797660   4844.325250
# std    4.194118e-04      0.040419      0.000374   2206.121126    533.509626
# min   -2.240000e-03     -0.153000     -0.002600      0.000000   2030.000000
# 25%   -2.620000e-04     -0.027600     -0.000195   3660.000000   4500.000000
# 50%   -2.240000e-06     -0.000623      0.000002   5060.000000   4870.000000
# 75%    2.600000e-04      0.026800      0.000210   6540.000000   5220.000000
# max    2.470000e-03      0.194000      0.002960  14200.000000   8360.000000

# %%
data_distance = np.hstack((np.array(data_1)[:, 1:8], np.array(data_1)[:, 8:10]))
print(data_distance)
print(data_distance.shape)
# Out:
# [[ 4.53e+02  1.88e+00 -1.13e-03 ... -1.25e-09  5.16e+03  5.13e+03]
#  [ 4.45e+02  6.80e+00  2.01e-02 ...  3.06e-07  5.44e+03  5.35e+03]
#  [ 4.38e+02  1.30e+01  3.05e-02 ...  2.26e-06  5.68e+03  5.56e+03]
#  ...
#  [ 8.94e+02  2.10e+02  2.39e+00 ...  2.27e-04  6.86e+03  4.82e+03]
#  [ 9.49e+02  2.09e+02  1.26e+00 ...  2.64e-04  6.86e+03  4.89e+03]
#  [ 9.98e+02  2.07e+02  2.44e-01 ...  2.61e-04  6.84e+03  4.96e+03]]
# (40000, 9)

# %%
H_scaler = MinMaxScaler(feature_range=(-1, 1))
H = H_scaler.fit_transform(data_distance[:,0:1])
Surge_scaler = MinMaxScaler(feature_range=(-1, 1))
Surge = Surge_scaler.fit_transform(data_distance[:,1:2])
Sway_scaler = MinMaxScaler(feature_range=(-1, 1))
Sway = Sway_scaler.fit_transform(data_distance[:,2:3])
Heave_scaler = MinMaxScaler(feature_range=(-1, 1))
Heave = Heave_scaler.fit_transform(data_distance[:,3:4])
Roll_scaler = MinMaxScaler(feature_range=(-1, 1))
Roll = Roll_scaler.fit_transform(data_distance[:,4:5]*1e6)
Pitch_scaler = MinMaxScaler(feature_range=(-1, 1))
Pitch = Pitch_scaler.fit_transform(data_distance[:,5:6])
Yaw_scaler = MinMaxScaler(feature_range=(-1, 1))
Yaw = Yaw_scaler.fit_transform(data_distance[:,6:7]*1e6)
Force1_scaler = MinMaxScaler(feature_range=(-1, 1))
Force1 = Force1_scaler.fit_transform(data_distance[:,7:8])
Force2_scaler = MinMaxScaler(feature_range=(-1, 1))
Force2 = Force2_scaler.fit_transform(data_distance[:,8:9])
# zong_data = np.hstack(())

# %%
def series_to_supervised(data, n_in, n_out, dropnan=True):
#      '''
#      说明：将每一个特征（输入+输出）的单步-目标步长数全数列举出来
#      '''
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    agg = concat(cols, axis=1)
    agg.columns = names
    if dropnan:
        agg.dropna(inplace=True)
    return agg
def deal_data1(data, features_number, time_steps):
    '''
    适用：单/多特征，单/多预测步长
    data：数据集（仅包括输入+输出，且输出仅有一列并在最后）
    feature_number：输入+输出变量数
    n_in：预测步长
    结果解释：输入+输出+所需预测步长的输出（当为单特征时，输入、输出为同一列）
    '''
    process_data = series_to_supervised(data, time_steps, 1, dropnan=True)
    a = []
    for i in range(features_number, features_number*(time_steps+1)-1):
        a.append(i)
        i = i+1
    process_data.drop(process_data.columns[a], axis=1, inplace=True)
    return process_data.values
def deal_data2(data, features_number, time_steps):
    '''
    适用：多特征，单/多预测步长，不适用于单特征
    data：数据集（仅包括输入+输出，且输出仅有一列并在最后）
    feature_number：输入+输出变量数
    n_in：预测步长
    结果解释：输入+所需预测步长的输出
    '''
    process_data = series_to_supervised(data, time_steps, 1, dropnan=True)
    a = []
    for i in range(features_number-1, features_number*(time_steps+1)-1):
        a.append(i)
        i = i+1
    process_data.drop(process_data.columns[a], axis=1, inplace=True)
    return process_data.values
def split_sequence(dataset, n_past):
    x, y = list(), list()
    for i in range(len(dataset)):
        end_ix = i + n_past
        if end_ix > len(dataset):
            break
        seq_x, seq_y = dataset[i:end_ix, :-1], dataset[i, -1]
        x.append(seq_x)
        y.append(seq_y)
    return np.array(x), np.array(y)

def loss_plot(history, epo, length, width):
    # plot history
    plt.figure(figsize = (length, width))
    # 将x周的刻度线方向设置向内
    plt.rcParams['xtick.direction'] = 'in'  
    # 将y轴的刻度方向设置向内
    plt.rcParams['ytick.direction'] = 'in'  
    #设置字体以便支持中文
    plt.rcParams['font.sans-serif']=['SimHei']
    #为正常显示负号
    plt.rcParams['axes.unicode_minus'] = False 
    plt.plot(history.history['loss'], label = 'train loss')
    plt.plot(history.history['val_loss'], label = 'valid loss')
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()
    print(np.hstack((np.array(history.history['loss']).reshape(epo,1), np.array(history.history['val_loss']).reshape(epo,1))))

from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,mean_absolute_percentage_error
def RNSE(valid_y,pre_Y):
    XP1 = valid_y.copy()
    XA1 = pre_Y.copy()
    print('RMSE(sklearn):',np.sqrt(mean_squared_error(XP1, XA1)))

def Acc(valid_y,pre_Y):
    XP1 = valid_y.copy()
    XA1 = pre_Y.copy()
    real1 = np.trapz(abs((XP1 - (XP1.sum()/(XP1.shape[0])))).reshape(XP1.shape[0],), dx=0.1)
    pre1 = np.trapz(abs((XA1 - (XP1.sum()/(XP1.shape[0])))).reshape(XA1.shape[0],), dx=0.1)
    Acc1 = 1 - abs(1 - (pre1/real1))
    print('Acc:', Acc1)

def FanGuiHua_surge(valid_sur_y,sur_pre_Y):
    fan_surge_real=Surge_scaler.inverse_transform(valid_sur_y)
    fan_surge_pre=Surge_scaler.inverse_transform(sur_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_surge_real[:200],color='blue',label='real')   #真实曲线
    plt.plot(fan_surge_pre[:200],color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_surge_real,fan_surge_pre)
    return fan_surge_real,fan_surge_pre
def FanGuiHua_pitch(valid_pit_y,pit_pre_Y):
    fan_pitch_real=Pitch_scaler.inverse_transform(valid_pit_y)
    fan_pitch_pre=Pitch_scaler.inverse_transform(pit_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_pitch_real[:200],color='blue',label='real')   #真实曲线
    plt.plot(fan_pitch_pre[:200],color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_pitch_real,fan_pitch_pre)
    return fan_pitch_real,fan_pitch_pre
def FanGuiHua_sway(valid_sway_y,sway_pre_Y):
    fan_sway_real=Sway_scaler.inverse_transform(valid_sway_y)
    fan_sway_pre=Sway_scaler.inverse_transform(sway_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_sway_real[:200],color='blue',label='real')   #真实曲线
    plt.plot(fan_sway_pre[:200],color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_sway_real,fan_sway_pre)
    return fan_sway_real,fan_sway_pre
def FanGuiHua_roll(valid_roll_y,roll_pre_Y):
    fan_roll_real=Roll_scaler.inverse_transform(valid_roll_y)
    fan_roll_pre=Roll_scaler.inverse_transform(roll_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_roll_real[:200],color='blue',label='real')   #真实曲线
    plt.plot(fan_roll_pre[:200],color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_roll_real,fan_roll_pre)
    return fan_roll_real,fan_roll_pre
def FanGuiHua_yaw(valid_yaw_y,yaw_pre_Y):
    fan_yaw_real=Yaw_scaler.inverse_transform(valid_yaw_y)
    fan_yaw_pre=Yaw_scaler.inverse_transform(yaw_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_yaw_real[:200],color='blue',label='real')   #真实曲线
    plt.plot(fan_yaw_pre[:200],color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_yaw_real,fan_yaw_pre)
    return fan_yaw_real,fan_yaw_pre
def FanGuiHua_heave(valid_hea_y,hea_pre_Y):
    fan_heave_real=Heave_scaler.inverse_transform(valid_hea_y)
    fan_heave_pre=Heave_scaler.inverse_transform(hea_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_heave_real[:200],color='blue',label='real')   #真实曲线
    plt.plot(fan_heave_pre[:200],color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_heave_real,fan_heave_pre)
    return fan_heave_real,fan_heave_pre
def FanGuiHua_force1(valid_for1_y,for1_pre_Y):
    fan_force1_real=Force1_scaler.inverse_transform(valid_for1_y)
    fan_force1_pre=Force1_scaler.inverse_transform(for1_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_force1_real,color='blue',label='real')   #真实曲线
    plt.plot(fan_force1_pre,color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_force1_real,fan_force1_pre)
    return fan_force1_real,fan_force1_pre
def FanGuiHua_force2(valid_for2_y,for2_pre_Y):
    fan_force2_real=Force2_scaler.inverse_transform(valid_for2_y)
    fan_force2_pre=Force2_scaler.inverse_transform(for2_pre_Y)
    plt.figure(figsize=(30,4), dpi=100)
    plt.plot(fan_force2_real,color='blue',label='real')   #真实曲线
    plt.plot(fan_force2_pre,color='orange',label='prediction') #预测曲线
    plt.legend()
    plt.show()
#     evaluate(fan_force2_real,fan_force2_pre)
    return fan_force2_real,fan_force2_pre

# 训练量=n_train_times_end-n_train_times_start
def split_train_valid(data_X, data_Y, n_train_times_start, n_train_times_end, n_valid_times):
    '''
    说明：将数据集划分为训练集和验证集
    疑问：先数据切割重组再划分数据集，先划分数据集再数据切割重组，有何区别影响？
    '''
    train_x, valid_x = data_X[n_train_times_start:n_train_times_end, :], data_X[n_train_times_end:n_valid_times, :]
    train_y, valid_y = data_Y[n_train_times_start:n_train_times_end], data_Y[n_train_times_end:n_valid_times]
    train_y = train_y.reshape((n_train_times_end-n_train_times_start, 1))
    valid_y = valid_y.reshape((n_valid_times-n_train_times_end, 1))
    return train_x, train_y, valid_x, valid_y

# %%
def Model_NN1(train_X, train_Y, valid_X, valid_Y, feature_number, lr=0.01, epochs=20, batch_size=256):
    input_layer = Input(shape=(feature_number,)) 
    D_layer1 = Dense(units = 150, activation = 'tanh')(input_layer)
    D_layer2 = Dense(units = 150, activation = 'tanh')(D_layer1)
    D_layer3 = Dense(units = 150, activation = 'tanh')(D_layer2)
    output_layer = Dense(1, activation = 'linear')(D_layer2)
    model = Model(inputs = input_layer, outputs = output_layer)
    adam = Adam(lr = lr)
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(train_X, train_Y, epochs=epochs, batch_size=batch_size, validation_data=(valid_X, valid_Y), verbose=2, shuffle=False)
    model_structure = model.summary()
    pre_train_Y = model.predict(train_X)
    pre_Y = model.predict(valid_X)
    return model, history, pre_train_Y, pre_Y

# %%
def Model_NN(train_X, train_Y, valid_X, valid_Y, lr=0.01, epochs=20, batch_size=256):
    model = Sequential() #初始化模型
    model.add(Dense(150,input_shape=(train_X.shape[1], ),activation='tanh')) #添加一个隐含层，注：只是第一个隐含层需指定input_dim
    model.add(Dense(150,activation='tanh'))
    model.add(Dense(150,activation='tanh'))
    model.add(Dense(1,activation='linear')) #添加输出层
    adam = Adam(lr = lr)
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(train_X, train_Y, epochs=epochs, batch_size=batch_size, validation_data=(valid_X, valid_Y), verbose=2, shuffle=False)
    model_structure = model.summary()
    pre_train_Y = model.predict(train_X)
    pre_Y = model.predict(valid_X)
    return model, history, pre_train_Y, pre_Y

# %%
# 归一化后的两个数据集
# 波浪-运动响应
# Force
# 输入500步长输出10步长
force150_scaled1 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[3500:,:], 4, 509)
force150_x1,force150_y1 = split_sequence(force150_scaled1, 500)
print(force150_x1.shape)
# # 输入100步长输出1步长
# force1100_scaled1 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[300:,:], 4, 100)
# force1100_x1,force1100_y1 = split_sequence(force1100_scaled1, 100)
# print(force1100_x1.shape)



# 输入500步长输出30步长
force150_scaled3 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[3480:,:], 4, 529)
force150_x3,force150_y3 = split_sequence(force150_scaled3, 500)
print(force150_x3.shape)
# # 输入100步长输出3步长
# force1100_scaled3 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[298:,:], 4, 102)
# force1100_x3,force1100_y3 = split_sequence(force1100_scaled3, 100)
# print(force1100_x3.shape)



# # 输入50步长输出5步长
# force150_scaled5 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[346:,:], 4, 54)
# force150_x5,force150_y5 = split_sequence(force150_scaled5, 50)
# print(force150_x5.shape)
# # 输入100步长输出5步长
# force1100_scaled5 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[296:,:], 4, 104)
# force1100_x5,force1100_y5 = split_sequence(force1100_scaled5, 100)
# print(force1100_x5.shape)



# # 输入50步长输出7步长
# force150_scaled7 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[344:,:], 4, 56)
# force150_x7,force150_y7 = split_sequence(force150_scaled7, 50)
# print(force150_x7.shape)
# # 输入100步长输出7步长
# force1100_scaled7 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[294:,:], 4, 106)
# force1100_x7,force1100_y7 = split_sequence(force1100_scaled7, 100)
# print(force1100_x7.shape)



# # 输入50步长输出9步长
# force150_scaled9 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[342:,:], 4, 58)
# force150_x9,force150_y9 = split_sequence(force150_scaled9, 50)
# print(force150_x9.shape)
# # 输入100步长输出9步长
# force1100_scaled9 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[292:,:], 4, 108)
# force1100_x9,force1100_y9 = split_sequence(force1100_scaled9, 100)
# print(force1100_x9.shape)



# 输入500步长输出20步长
force150_scaled2 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[3490:,:], 4, 519)
force150_x2,force150_y2 = split_sequence(force150_scaled2, 500)
print(force150_x2.shape)
# # 输入100步长输出2步长
# force1100_scaled2 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[299:,:], 4, 101)
# force1100_x2,force1100_y2 = split_sequence(force1100_scaled2, 100)
# print(force1100_x2.shape)


# 输入500步长输出40步长
force150_scaled4 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[3470:,:], 4, 539)
force150_x4,force150_y4 = split_sequence(force150_scaled4, 500)
print(force150_x4.shape)
# # 输入100步长输出4步长
# force1100_scaled4 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[297:,:], 4, 103)
# force1100_x4,force1100_y4 = split_sequence(force1100_scaled4, 100)
# print(force1100_x4.shape)



# # 输入50步长输出6步长
# force150_scaled6 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[345:,:], 4, 55)
# force150_x6,force150_y6 = split_sequence(force150_scaled6, 50)
# print(force150_x6.shape)
# # 输入100步长输出6步长
# force1100_scaled6 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[295:,:], 4, 105)
# force1100_x6,force1100_y6 = split_sequence(force1100_scaled6, 100)
# print(force1100_x6.shape)



# # 输入50步长输出8步长
# force150_scaled8 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[343:,:], 4, 57)
# force150_x8,force150_y8 = split_sequence(force150_scaled8, 50)
# print(force150_x8.shape)
# # 输入100步长输出8步长
# force1100_scaled8 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[293:,:], 4, 107)
# force1100_x8,force1100_y8 = split_sequence(force1100_scaled8, 100)
# print(force1100_x8.shape)
# Out:
# (35492, 500, 3)
# (35492, 500, 3)
# (35492, 500, 3)
# (35492, 500, 3)

# %%
print(force150_y1)
print(force150_y2)
print(force150_y3)
print(force150_y4)
# Out:
# [ 0.02535211  0.01830986  0.01408451 ... -0.25492958 -0.26056338
#  -0.26619718]
# [ 0.02535211  0.01830986  0.01408451 ... -0.25492958 -0.26056338
#  -0.26619718]
# [ 0.02535211  0.01830986  0.01408451 ... -0.25492958 -0.26056338
#  -0.26619718]
# [ 0.02535211  0.01830986  0.01408451 ... -0.25492958 -0.26056338
#  -0.26619718]

# %%
# 归一化后的两个数据集
# 波浪-运动响应
# 归一化后的两个数据集
# 波浪-运动响应
# Heave
# 输入500步长输出10步长
heave50_scaled1 = deal_data2(np.hstack((H,Heave))[3500:,:], 2, 509)
heave50_x1,heave50_y1 = split_sequence(heave50_scaled1, 500)
print(heave50_x1.shape)
# # 输入100步长输出1步长
# heave100_scaled1 = deal_data2(np.hstack((H,Heave))[300:,:], 2, 100)
# heave100_x1,heave100_y1 = split_sequence(heave100_scaled1, 100)
# print(heave100_x1.shape)



# 输入500步长输出30步长
heave50_scaled3 = deal_data2(np.hstack((H,Heave))[3480:,:], 2, 529)
heave50_x3,heave50_y3 = split_sequence(heave50_scaled3, 500)
print(heave50_x3.shape)
# # 输入100步长输出3步长
# heave100_scaled3 = deal_data2(np.hstack((H,Heave))[298:,:], 2, 102)
# heave100_x3,heave100_y3 = split_sequence(heave100_scaled3, 100)
# print(heave100_x3.shape)



# # 输入50步长输出5步长
# heave50_scaled5 = deal_data2(np.hstack((H,Heave))[346:,:], 2, 54)
# heave50_x5,heave50_y5 = split_sequence(heave50_scaled5, 50)
# print(heave50_x5.shape)
# # 输入100步长输出5步长
# heave100_scaled5 = deal_data2(np.hstack((H,Heave))[296:,:], 2, 104)
# heave100_x5,heave100_y5 = split_sequence(heave100_scaled5, 100)
# print(heave100_x5.shape)



# # 输入50步长输出7步长
# heave50_scaled7 = deal_data2(np.hstack((H,Heave))[344:,:], 2, 56)
# heave50_x7,heave50_y7 = split_sequence(heave50_scaled7, 50)
# print(heave50_x7.shape)
# # 输入100步长输出7步长
# heave100_scaled7 = deal_data2(np.hstack((H,Heave))[294:,:], 2, 106)
# heave100_x7,heave100_y7 = split_sequence(heave100_scaled7, 100)
# print(heave100_x7.shape)



# # 输入50步长输出9步长
# heave50_scaled9 = deal_data2(np.hstack((H,Heave))[342:,:], 2, 58)
# heave50_x9,heave50_y9 = split_sequence(heave50_scaled9, 50)
# print(heave50_x9.shape)
# # 输入100步长输出9步长
# heave100_scaled9 = deal_data2(np.hstack((H,Heave))[292:,:], 2, 108)
# heave100_x9,heave100_y9 = split_sequence(heave100_scaled9, 100)
# print(heave100_x9.shape)



# 输入500步长输出20步长
heave50_scaled2 = deal_data2(np.hstack((H,Heave))[3490:,:], 2, 519)
heave50_x2,heave50_y2 = split_sequence(heave50_scaled2, 500)
print(heave50_x2.shape)
# # 输入100步长输出2步长
# heave100_scaled2 = deal_data2(np.hstack((H,Heave))[299:,:], 2, 101)
# heave100_x2,heave100_y2 = split_sequence(heave100_scaled2, 100)
# print(heave100_x2.shape)


# 输入500步长输出40步长
heave50_scaled4 = deal_data2(np.hstack((H,Heave))[3470:,:], 2, 539)
heave50_x4,heave50_y4 = split_sequence(heave50_scaled4, 500)
print(heave50_x4.shape)
# # 输入100步长输出4步长
# heave100_scaled4 = deal_data2(np.hstack((H,Heave))[297:,:], 2, 103)
# heave100_x4,heave100_y4 = split_sequence(heave100_scaled4, 100)
# print(heave100_x4.shape)



# # 输入50步长输出6步长
# heave50_scaled6 = deal_data2(np.hstack((H,Heave))[345:,:], 2, 55)
# heave50_x6,heave50_y6 = split_sequence(heave50_scaled6, 50)
# print(heave50_x6.shape)
# # 输入100步长输出6步长
# heave100_scaled6 = deal_data2(np.hstack((H,Heave))[295:,:], 2, 105)
# heave100_x6,heave100_y6 = split_sequence(heave100_scaled6, 100)
# print(heave100_x6.shape)



# # 输入50步长输出8步长
# heave50_scaled8 = deal_data2(np.hstack((H,Heave))[343:,:], 2, 57)
# heave50_x8,heave50_y8 = split_sequence(heave50_scaled8, 50)
# print(heave50_x8.shape)
# # 输入100步长输出8步长
# heave100_scaled8 = deal_data2(np.hstack((H,Heave))[293:,:], 2, 107)
# heave100_x8,heave100_y8 = split_sequence(heave100_scaled8, 100)
# print(heave100_x8.shape)


# Surge
# 输入500步长输出10步长
surge50_scaled1 = deal_data2(np.hstack((H,Surge))[3500:,:], 2, 509)
surge50_x1,surge50_y1 = split_sequence(surge50_scaled1, 500)
print(surge50_x1.shape)
# # 输入100步长输出1步长
# surge100_scaled1 = deal_data2(np.hstack((H,Surge))[300:,:], 2, 100)
# surge100_x1,surge100_y1 = split_sequence(surge100_scaled1, 100)
# print(surge100_x1.shape)



# 输入500步长输出30步长
surge50_scaled3 = deal_data2(np.hstack((H,Surge))[3480:,:], 2, 529)
surge50_x3,surge50_y3 = split_sequence(surge50_scaled3, 500)
print(surge50_x3.shape)
# # 输入100步长输出3步长
# surge100_scaled3 = deal_data2(np.hstack((H,Surge))[298:,:], 2, 102)
# surge100_x3,surge100_y3 = split_sequence(surge100_scaled3, 100)
# print(surge100_x3.shape)



# # 输入50步长输出5步长
# surge50_scaled5 = deal_data2(np.hstack((H,Surge))[346:,:], 2, 54)
# surge50_x5,surge50_y5 = split_sequence(surge50_scaled5, 50)
# print(surge50_x5.shape)
# # 输入100步长输出5步长
# surge100_scaled5 = deal_data2(np.hstack((H,Surge))[296:,:], 2, 104)
# surge100_x5,surge100_y5 = split_sequence(surge100_scaled5, 100)
# print(surge100_x5.shape)



# # 输入50步长输出7步长
# surge50_scaled7 = deal_data2(np.hstack((H,Surge))[344:,:], 2, 56)
# surge50_x7,surge50_y7 = split_sequence(surge50_scaled7, 50)
# print(surge50_x7.shape)
# # 输入100步长输出7步长
# surge100_scaled7 = deal_data2(np.hstack((H,Surge))[294:,:], 2, 106)
# surge100_x7,surge100_y7 = split_sequence(surge100_scaled7, 100)
# print(surge100_x7.shape)



# # 输入50步长输出9步长
# surge50_scaled9 = deal_data2(np.hstack((H,Surge))[342:,:], 2, 58)
# surge50_x9,surge50_y9 = split_sequence(surge50_scaled9, 50)
# print(surge50_x9.shape)
# # 输入100步长输出9步长
# surge100_scaled9 = deal_data2(np.hstack((H,Surge))[292:,:], 2, 108)
# surge100_x9,surge100_y9 = split_sequence(surge100_scaled9, 100)
# print(surge100_x9.shape)



# 输入500步长输出20步长
surge50_scaled2 = deal_data2(np.hstack((H,Surge))[3490:,:], 2, 519)
surge50_x2,surge50_y2 = split_sequence(surge50_scaled2, 500)
print(surge50_x2.shape)
# 输入100步长输出2步长
# surge100_scaled2 = deal_data2(np.hstack((H,Surge))[299:,:], 2, 101)
# surge100_x2,surge100_y2 = split_sequence(surge100_scaled2, 100)
# print(surge100_x2.shape)


# 输入500步长输出40步长
surge50_scaled4 = deal_data2(np.hstack((H,Surge))[3470:,:], 2, 539)
surge50_x4,surge50_y4 = split_sequence(surge50_scaled4, 500)
print(surge50_x4.shape)
# # 输入100步长输出4步长
# surge100_scaled4 = deal_data2(np.hstack((H,Surge))[297:,:], 2, 103)
# surge100_x4,surge100_y4 = split_sequence(surge100_scaled4, 100)
# print(surge100_x4.shape)



# # 输入50步长输出6步长
# surge50_scaled6 = deal_data2(np.hstack((H,Surge))[345:,:], 2, 55)
# surge50_x6,surge50_y6 = split_sequence(surge50_scaled6, 50)
# print(surge50_x6.shape)
# # 输入100步长输出6步长
# surge100_scaled6 = deal_data2(np.hstack((H,Surge))[295:,:], 2, 105)
# surge100_x6,surge100_y6 = split_sequence(surge100_scaled6, 100)
# print(surge100_x6.shape)



# # 输入50步长输出8步长
# surge50_scaled8 = deal_data2(np.hstack((H,Surge))[343:,:], 2, 57)
# surge50_x8,surge50_y8 = split_sequence(surge50_scaled8, 50)
# print(surge50_x8.shape)
# # 输入100步长输出8步长
# surge100_scaled8 = deal_data2(np.hstack((H,Surge))[293:,:], 2, 107)
# surge100_x8,surge100_y8 = split_sequence(surge100_scaled8, 100)
# print(surge100_x8.shape)


# Pitch
# 输入500步长输出10步长
pitch50_scaled1 = deal_data2(np.hstack((H,Pitch))[3500:,:], 2, 509)
pitch50_x1,pitch50_y1 = split_sequence(pitch50_scaled1, 500)
print(pitch50_x1.shape)
# # 输入100步长输出1步长
# pitch100_scaled1 = deal_data2(np.hstack((H,Pitch))[300:,:], 2, 100)
# pitch100_x1,pitch100_y1 = split_sequence(pitch100_scaled1, 100)
# print(pitch100_x1.shape)



# 输入500步长输出30步长
pitch50_scaled3 = deal_data2(np.hstack((H,Pitch))[3480:,:], 2, 529)
pitch50_x3,pitch50_y3 = split_sequence(pitch50_scaled3, 500)
print(pitch50_x3.shape)
# # 输入100步长输出3步长
# pitch100_scaled3 = deal_data2(np.hstack((H,Pitch))[298:,:], 2, 102)
# pitch100_x3,pitch100_y3 = split_sequence(pitch100_scaled3, 100)
# print(pitch100_x3.shape)



# # 输入50步长输出5步长
# pitch50_scaled5 = deal_data2(np.hstack((H,Pitch))[346:,:], 2, 54)
# pitch50_x5,pitch50_y5 = split_sequence(pitch50_scaled5, 50)
# print(pitch50_x5.shape)
# # 输入100步长输出5步长
# pitch100_scaled5 = deal_data2(np.hstack((H,Pitch))[296:,:], 2, 104)
# pitch100_x5,pitch100_y5 = split_sequence(pitch100_scaled5, 100)
# print(pitch100_x5.shape)



# # 输入50步长输出7步长
# pitch50_scaled7 = deal_data2(np.hstack((H,Pitch))[344:,:], 2, 56)
# pitch50_x7,pitch50_y7 = split_sequence(pitch50_scaled7, 50)
# print(pitch50_x7.shape)
# # 输入100步长输出7步长
# pitch100_scaled7 = deal_data2(np.hstack((H,Pitch))[294:,:], 2, 106)
# pitch100_x7,pitch100_y7 = split_sequence(pitch100_scaled7, 100)
# print(pitch100_x7.shape)



# # 输入50步长输出9步长
# pitch50_scaled9 = deal_data2(np.hstack((H,Pitch))[342:,:], 2, 58)
# pitch50_x9,pitch50_y9 = split_sequence(pitch50_scaled9, 50)
# print(pitch50_x9.shape)
# # 输入100步长输出9步长
# pitch100_scaled9 = deal_data2(np.hstack((H,Pitch))[292:,:], 2, 108)
# pitch100_x9,pitch100_y9 = split_sequence(pitch100_scaled9, 100)
# print(pitch100_x9.shape)



# 输入500步长输出20步长
pitch50_scaled2 = deal_data2(np.hstack((H,Pitch))[3490:,:], 2, 519)
pitch50_x2,pitch50_y2 = split_sequence(pitch50_scaled2, 500)
print(pitch50_x2.shape)
# # 输入100步长输出2步长
# pitch100_scaled2 = deal_data2(np.hstack((H,Pitch))[299:,:], 2, 101)
# pitch100_x2,pitch100_y2 = split_sequence(pitch100_scaled2, 100)
# print(pitch100_x2.shape)


# 输入500步长输出40步长
pitch50_scaled4 = deal_data2(np.hstack((H,Pitch))[3470:,:], 2, 539)
pitch50_x4,pitch50_y4 = split_sequence(pitch50_scaled4, 500)
print(pitch50_x4.shape)
# # 输入100步长输出4步长
# pitch100_scaled4 = deal_data2(np.hstack((H,Pitch))[297:,:], 2, 103)
# pitch100_x4,pitch100_y4 = split_sequence(pitch100_scaled4, 100)
# print(pitch100_x4.shape)



# # 输入50步长输出6步长
# pitch50_scaled6 = deal_data2(np.hstack((H,Pitch))[345:,:], 2, 55)
# pitch50_x6,pitch50_y6 = split_sequence(pitch50_scaled6, 50)
# print(pitch50_x6.shape)
# # 输入100步长输出6步长
# pitch100_scaled6 = deal_data2(np.hstack((H,Pitch))[295:,:], 2, 105)
# pitch100_x6,pitch100_y6 = split_sequence(pitch100_scaled6, 100)
# print(pitch100_x6.shape)



# # 输入50步长输出8步长
# pitch50_scaled8 = deal_data2(np.hstack((H,Pitch))[343:,:], 2, 57)
# pitch50_x8,pitch50_y8 = split_sequence(pitch50_scaled8, 50)
# print(pitch50_x8.shape)
# # 输入100步长输出8步长
# pitch100_scaled8 = deal_data2(np.hstack((H,Pitch))[293:,:], 2, 107)
# pitch100_x8,pitch100_y8 = split_sequence(pitch100_scaled8, 100)
# print(pitch100_x8.shape)
# Out:
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)
# (35492, 500, 1)

# %% [markdown]
# ### 模型比较

# %%
# GRU
def Model_GRU(train_X, train_Y, valid_X, valid_Y, lr=0.01, epochs=20, batch_size=256):
    model = Sequential()
    model.add(GRU(25, activation='tanh', return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))  #25×5的数据输入
    model.add(Dropout(0.3))
    model.add(GRU(100, activation='tanh', return_sequences=True))
    model.add(Dropout(0.3))
    model.add(GRU(100, activation='tanh'))
    model.add(Dropout(0.3))
    model.add(Dense(train_Y.shape[1])) 
    model.add(Activation('tanh'))
    adam = Adam(lr = lr)
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(train_X, train_Y, epochs=epochs, batch_size=batch_size, validation_data=(valid_X, valid_Y), verbose=2, shuffle=False)
    model_structure = model.summary()
    pre_Y = model.predict(valid_X)
    return model, history, pre_Y

# LSTM
def Model_LSTM(train_X, train_Y, valid_X, valid_Y, lr=0.01, epochs=20, batch_size=256):
    model = Sequential()
    model.add(LSTM(25, activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2])))  #25×5的数据输入
    model.add(Dense(train_Y.shape[1])) 
    model.add(Activation('tanh'))
    adam = Adam(lr = lr)
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(train_X, train_Y, epochs=epochs, batch_size=batch_size, validation_data=(valid_X, valid_Y), verbose=2, shuffle=False)
    model_structure = model.summary()
    pre_Y = model.predict(valid_X)
    return model, history, pre_Y

# BiLSTM
from keras.layers import LeakyReLU
def Model_BiLSTM(train_X, train_Y, valid_X, valid_Y, lr=0.01, epochs=20, batch_size=256):
    model = Sequential()
    model.add(Bidirectional(LSTM(25, batch_input_shape=(24, train_X.shape[1], train_X.shape[2]),stateful=False), merge_mode='concat'))  #25×5的数据输入
    model.add(LeakyReLU(alpha=0.3))
    model.add(Dense(train_Y.shape[1])) 
    model.add(Activation('tanh'))
    adam = Adam(lr = lr)
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(train_X, train_Y, epochs=epochs, batch_size=batch_size, validation_data=(valid_X, valid_Y), verbose=2, shuffle=False)
    model_structure = model.summary()
    pre_Y = model.predict(valid_X)
    return model, history, pre_Y
# # Bi-StatefulLSTM
# def Model_BiSLSTM(train_X, train_Y, valid_X, valid_Y, lr=0.01, epochs=20, Batch_size=256):
#     model = Sequential() 
#     model.add(Bidirectional(LSTM(25, batch_input_shape=(24, train_X.shape[1], train_X.shape[2]),stateful=True,return_sequences=True), merge_mode='concat'))  
#     model.add(Bidirectional(LSTM(25,stateful=True), merge_mode='concat'))  
#     model.add(Dense(train_Y.shape[1])) 
#     model.add(Activation('tanh'))
#     adam = Adam(lr = lr)
#     model.compile(loss='mse', optimizer='adam')
#     history = model.fit(train_X, train_Y, epochs=epochs, batch_size=Batch_size, validation_data=(valid_X, valid_Y), verbose=2, shuffle=False)
#     model.reset_states()
#     model_structure = model.summary()
#     pre_Y = model.predict(valid_X,batch_size=Batch_size)
#     return model, history, pre_Y

# CNN-BiLSTM-Attention
from keras.layers import Input, Dense, LSTM, merge ,Conv1D, Dropout, Bidirectional, Multiply
from keras.models import Model
from attention_utils import get_activations
from keras.layers import merge
from keras.layers.core import *
from keras.layers.recurrent import LSTM
from keras.models import *
SINGLE_ATTENTION_VECTOR = False
def attention_3d_block(inputs):
    # inputs.shape = (batch_size, time_steps, input_dim)
    input_dim = int(inputs.shape[2])
    a = inputs
    #a = Permute((2, 1))(inputs)
    #a = Reshape((input_dim, TIME_STEPS))(a) # this line is not useful. It's just to know which dimension is what.
    a = Dense(input_dim, activation='softmax')(a)
    if SINGLE_ATTENTION_VECTOR:
        a = Lambda(lambda x: K.mean(x, axis=1), name='dim_reduction')(a)
        a = RepeatVector(input_dim)(a)
    a_probs = Permute((1, 2), name='attention_vec')(a)

    output_attention_mul = merge([inputs, a_probs], name='attention_mul', mode='mul')
    return output_attention_mul

# 注意力机制的另一种写法 适合上述报错使用 来源:https://blog.csdn.net/uhauha2929/article/details/80733255
def attention_3d_block2(inputs, single_attention_vector=False):
    # 如果上一层是LSTM，需要return_sequences=True
    # inputs.shape = (batch_size, time_steps, input_dim)
    time_steps = K.int_shape(inputs)[1]
    input_dim = K.int_shape(inputs)[2]
    a = Permute((2, 1))(inputs)
    a = Dense(time_steps, activation='tanh')(a)
    if single_attention_vector:
        a = Lambda(lambda x: K.mean(x, axis=1))(a)
        a = RepeatVector(input_dim)(a)

    a_probs = Permute((2, 1))(a)
    # 乘上了attention权重，但是并没有求和，好像影响不大
    # 如果分类任务，进行Flatten展开就可以了
    # element-wise
    output_attention_mul = Multiply()([inputs, a_probs])
    return output_attention_mul

def attention_model(train_X, train_Y, valid_X, valid_Y, lr=0.01, epochs=20, batch_size=256):
    inputs = Input(shape=(TIME_STEPS, INPUT_DIMS))

    x = Conv1D(filters = 64, kernel_size = 1, activation = 'tanh')(inputs)  #, padding = 'same'
    x = Dropout(0.1)(x)

    #lstm_out = Bidirectional(LSTM(lstm_units, activation='relu'), name='bilstm')(x)
    #对于GPU可以使用CuDNNLSTM
    lstm_out1 = LSTM(lstm_units, activation='tanh', return_sequences=True)(x)
#     lstm_out1 = LeakyReLU(alpha=0.3)(lstm_out1)
#     lstm_out1 = Dropout(0.3)(lstm_out1)
#     lstm_out2 = Bidirectional(LSTM(lstm_units, return_sequences=True))(lstm_out1)
#     lstm_out3 = LSTM(lstm_units)(lstm_out2)
#     lstm_out1 = Dropout(0.1)(lstm_out1)
    attention_mul = attention_3d_block2(lstm_out1)
    attention_mul = Flatten()(attention_mul)

    output = Dense(1)(attention_mul)
    model = Model(inputs=[inputs], outputs=output)
    adam = Adam(lr = lr)
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(train_X, train_Y, epochs=epochs, batch_size=batch_size, validation_data=(valid_X, valid_Y), verbose=2, shuffle=False)
    model.reset_states()
    model_structure = model.summary()
    pre_Y = model.predict(valid_X,batch_size=batch_size)
    return model, history, pre_Y

# %% [markdown]
# #### 系泊缆力联合预测（时间窗500输出；步长10）

# %%
train_heave50_x1, train_heave50_y1, valid_heave50_x1, valid_heave50_y1 = split_train_valid(heave50_x1,heave50_y1, 4500, 7500, 12000)
train_surge50_x1, train_surge50_y1, valid_surge50_x1, valid_surge50_y1 = split_train_valid(surge50_x1,surge50_y1, 4200, 7500, 12000)                                                             
train_pitch50_x1, train_pitch50_y1, valid_pitch50_x1, valid_pitch50_y1 = split_train_valid(pitch50_x1,pitch50_y1, 4500, 7500, 12000)

# %%
INPUT_DIMS = 1
TIME_STEPS = 500
lstm_units = 64
# 未来运动预测模型建立
heave50_model1, heave50_history1, pre_heave50_Y1 = attention_model(train_heave50_x1, train_heave50_y1, valid_heave50_x1, valid_heave50_y1, lr=0.1, epochs=30, batch_size=50)
# train_heave100_x1, train_heave100_y1, valid_heave100_x1, valid_heave100_y1 = split_train_valid(heave100_x1,heave100_y1, 6900, 7500, 8000)
# heave100_model1, heave100_history1, pre_heave100_Y1 = Model_LSTM(train_heave100_x1, train_heave100_y1, valid_heave100_x1, valid_heave100_y1, lr=0.1, epochs=60, batch_size=50)

surge50_model1, surge50_history1, pre_surge50_Y1 = attention_model(train_surge50_x1, train_surge50_y1, valid_surge50_x1, valid_surge50_y1, lr=1.3, epochs=30, batch_size=50)
# train_surge100_x1, train_surge100_y1, valid_surge100_x1, valid_surge100_y1 = split_train_valid(surge100_x1,surge100_y1, 6600, 7500, 8000)
# surge100_model1, surge100_history1, pre_surge100_Y1 = Model_LSTM(train_surge100_x1, train_surge100_y1, valid_surge100_x1, valid_surge100_y1, lr=1.3, epochs=60, batch_size=50)
                                                                 
pitch50_model1, pitch50_history1, pre_pitch50_Y1 = attention_model(train_pitch50_x1, train_pitch50_y1, valid_pitch50_x1, valid_pitch50_y1, lr=0.35, epochs=30, batch_size=50)
# train_pitch100_x1, train_pitch100_y1, valid_pitch100_x1, valid_pitch100_y1 = split_train_valid(pitch100_x1,pitch100_y1, 6900, 7500, 8000)
# pitch100_model1, pitch100_history1, pre_pitch100_Y1 = Model_LSTM(train_pitch100_x1, train_pitch100_y1, valid_pitch100_x1, valid_pitch100_y1, lr=0.35, epochs=60, batch_size=50)
# Out:
# Train on 3000 samples, validate on 4500 samples
# Epoch 1/30
#  - 29s - loss: 0.0719 - val_loss: 0.0434
# Epoch 2/30
#  - 30s - loss: 0.0334 - val_loss: 0.0201
# Epoch 3/30
#  - 31s - loss: 0.0156 - val_loss: 0.0130
# Epoch 4/30
#  - 32s - loss: 0.0127 - val_loss: 0.0123
# Epoch 5/30
#  - 32s - loss: 0.0104 - val_loss: 0.0105
# Epoch 6/30
#  - 31s - loss: 0.0087 - val_loss: 0.0094
# Epoch 7/30
#  - 31s - loss: 0.0071 - val_loss: 0.0093
# Epoch 8/30
#  - 35s - loss: 0.0065 - val_loss: 0.0090
# Epoch 9/30
#  - 36s - loss: 0.0067 - val_loss: 0.0129
# Epoch 10/30
#  - 38s - loss: 0.0074 - val_loss: 0.0084
# Epoch 11/30
#  - 37s - loss: 0.0065 - val_loss: 0.0129
# Epoch 12/30
#  - 35s - loss: 0.0083 - val_loss: 0.0092
# Epoch 13/30
#  - 34s - loss: 0.0064 - val_loss: 0.0079
# Epoch 14/30
#  - 33s - loss: 0.0047 - val_loss: 0.0087
# Epoch 15/30
#  - 34s - loss: 0.0060 - val_loss: 0.0099
# Epoch 16/30
#  - 35s - loss: 0.0042 - val_loss: 0.0071
# Epoch 17/30
#  - 35s - loss: 0.0050 - val_loss: 0.0062
# Epoch 18/30
#  - 32s - loss: 0.0037 - val_loss: 0.0062
# Epoch 19/30
#  - 32s - loss: 0.0030 - val_loss: 0.0061
# Epoch 20/30
#  - 32s - loss: 0.0026 - val_loss: 0.0069
# Epoch 21/30
#  - 32s - loss: 0.0031 - val_loss: 0.0062
# Epoch 22/30
#  - 34s - loss: 0.0032 - val_loss: 0.0075
# Epoch 23/30
#  - 35s - loss: 0.0037 - val_loss: 0.0077
# Epoch 24/30
#  - 32s - loss: 0.0038 - val_loss: 0.0089
# Epoch 25/30
#  - 32s - loss: 0.0046 - val_loss: 0.0080
# Epoch 26/30
#  - 32s - loss: 0.0037 - val_loss: 0.0061
# Epoch 27/30
#  - 32s - loss: 0.0034 - val_loss: 0.0072
# Epoch 28/30
#  - 31s - loss: 0.0042 - val_loss: 0.0081
# Epoch 29/30
#  - 33s - loss: 0.0031 - val_loss: 0.0093
# Epoch 30/30
#  - 33s - loss: 0.0045 - val_loss: 0.0076
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 500, 1)       0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 500, 64)      128         input_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 500, 64)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 500, 64)      33024       dropout_1[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 64, 500)      0           lstm_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64, 500)      250500      permute_1[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 500, 64)      0           dense_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 500, 64)      0           lstm_1[0][0]
#                                                                  permute_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 32000)        0           multiply_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            32001       flatten_1[0][0]
# ==================================================================================================
# Total params: 315,653
# Trainable params: 315,653
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 3300 samples, validate on 4500 samples
# Epoch 1/30
#  - 37s - loss: 0.0278 - val_loss: 0.0347
# Epoch 2/30
#  - 37s - loss: 0.0224 - val_loss: 0.0126
# Epoch 3/30
#  - 38s - loss: 0.0117 - val_loss: 0.0118
# Epoch 4/30
#  - 38s - loss: 0.0088 - val_loss: 0.0074
# Epoch 5/30
#  - 36s - loss: 0.0075 - val_loss: 0.0085
# Epoch 6/30
#  - 38s - loss: 0.0069 - val_loss: 0.0078
# Epoch 7/30
#  - 37s - loss: 0.0064 - val_loss: 0.0084
# Epoch 8/30
#  - 38s - loss: 0.0061 - val_loss: 0.0078
# Epoch 9/30
#  - 38s - loss: 0.0058 - val_loss: 0.0085
# Epoch 10/30
#  - 38s - loss: 0.0056 - val_loss: 0.0081
# Epoch 11/30
#  - 38s - loss: 0.0053 - val_loss: 0.0079
# Epoch 12/30
#  - 38s - loss: 0.0051 - val_loss: 0.0074
# Epoch 13/30
#  - 38s - loss: 0.0045 - val_loss: 0.0096
# Epoch 14/30
#  - 38s - loss: 0.0057 - val_loss: 0.0081
# Epoch 15/30
#  - 38s - loss: 0.0050 - val_loss: 0.0200
# Epoch 16/30
#  - 39s - loss: 0.0058 - val_loss: 0.0078
# Epoch 17/30
#  - 39s - loss: 0.0047 - val_loss: 0.0088
# Epoch 18/30
#  - 39s - loss: 0.0037 - val_loss: 0.0098
# Epoch 19/30
#  - 39s - loss: 0.0036 - val_loss: 0.0082
# Epoch 20/30
#  - 38s - loss: 0.0035 - val_loss: 0.0101
# Epoch 21/30
#  - 39s - loss: 0.0046 - val_loss: 0.0094
# Epoch 22/30
#  - 40s - loss: 0.0068 - val_loss: 0.0067
# Epoch 23/30
#  - 40s - loss: 0.0045 - val_loss: 0.0105
# Epoch 24/30
#  - 38s - loss: 0.0039 - val_loss: 0.0083
# Epoch 25/30
#  - 39s - loss: 0.0034 - val_loss: 0.0089
# Epoch 26/30
#  - 39s - loss: 0.0032 - val_loss: 0.0090
# Epoch 27/30
#  - 39s - loss: 0.0037 - val_loss: 0.0080
# Epoch 28/30
#  - 39s - loss: 0.0031 - val_loss: 0.0085
# Epoch 29/30
#  - 38s - loss: 0.0025 - val_loss: 0.0084
# Epoch 30/30
#  - 38s - loss: 0.0022 - val_loss: 0.0081
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 500, 1)       0
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 500, 64)      128         input_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 500, 64)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 500, 64)      33024       dropout_2[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 64, 500)      0           lstm_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64, 500)      250500      permute_3[0][0]
# __________________________________________________________________________________________________
# permute_4 (Permute)             (None, 500, 64)      0           dense_3[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 500, 64)      0           lstm_2[0][0]
#                                                                  permute_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 32000)        0           multiply_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            32001       flatten_2[0][0]
# ==================================================================================================
# Total params: 315,653
# Trainable params: 315,653
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 3000 samples, validate on 4500 samples
# Epoch 1/30
#  - 36s - loss: 0.0540 - val_loss: 0.0299
# Epoch 2/30
#  - 36s - loss: 0.0312 - val_loss: 0.0247
# Epoch 3/30
#  - 37s - loss: 0.0261 - val_loss: 0.0243
# Epoch 4/30
#  - 38s - loss: 0.0242 - val_loss: 0.0230
# Epoch 5/30
#  - 39s - loss: 0.0218 - val_loss: 0.0219
# Epoch 6/30
#  - 39s - loss: 0.0200 - val_loss: 0.0211
# Epoch 7/30
#  - 38s - loss: 0.0184 - val_loss: 0.0216
# Epoch 8/30
#  - 39s - loss: 0.0169 - val_loss: 0.0218
# Epoch 9/30
#  - 38s - loss: 0.0153 - val_loss: 0.0244
# Epoch 10/30
#  - 39s - loss: 0.0171 - val_loss: 0.0251
# Epoch 11/30
#  - 38s - loss: 0.0143 - val_loss: 0.0240
# Epoch 12/30
#  - 39s - loss: 0.0140 - val_loss: 0.0333
# Epoch 13/30
#  - 40s - loss: 0.0158 - val_loss: 0.0249
# Epoch 14/30
#  - 40s - loss: 0.0138 - val_loss: 0.0313
# Epoch 15/30
#  - 40s - loss: 0.0158 - val_loss: 0.0254
# Epoch 16/30
#  - 40s - loss: 0.0154 - val_loss: 0.0311
# Epoch 17/30
#  - 40s - loss: 0.0162 - val_loss: 0.0268
# Epoch 18/30
#  - 40s - loss: 0.0110 - val_loss: 0.0264
# Epoch 19/30
#  - 39s - loss: 0.0109 - val_loss: 0.0240
# Epoch 20/30
#  - 40s - loss: 0.0121 - val_loss: 0.0273
# Epoch 21/30
#  - 40s - loss: 0.0113 - val_loss: 0.0238
# Epoch 22/30
#  - 40s - loss: 0.0106 - val_loss: 0.0300
# Epoch 23/30
#  - 40s - loss: 0.0099 - val_loss: 0.0247
# Epoch 24/30
#  - 40s - loss: 0.0108 - val_loss: 0.0269
# Epoch 25/30
#  - 40s - loss: 0.0130 - val_loss: 0.0312
# Epoch 26/30
#  - 41s - loss: 0.0100 - val_loss: 0.0336
# Epoch 27/30
#  - 40s - loss: 0.0143 - val_loss: 0.0272
# Epoch 28/30
#  - 41s - loss: 0.0099 - val_loss: 0.0276
# Epoch 29/30
#  - 41s - loss: 0.0140 - val_loss: 0.0261
# Epoch 30/30
#  - 40s - loss: 0.0098 - val_loss: 0.0252
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 500, 1)       0
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 500, 64)      128         input_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 500, 64)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 500, 64)      33024       dropout_3[0][0]
# __________________________________________________________________________________________________
# permute_5 (Permute)             (None, 64, 500)      0           lstm_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64, 500)      250500      permute_5[0][0]
# __________________________________________________________________________________________________
# permute_6 (Permute)             (None, 500, 64)      0           dense_5[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 500, 64)      0           lstm_3[0][0]
#                                                                  permute_6[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 32000)        0           multiply_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            32001       flatten_3[0][0]
# ==================================================================================================
# Total params: 315,653
# Trainable params: 315,653
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
pretrain_heave50_Y1 = heave50_model1.predict(train_heave50_x1)
# pretrain_heave100_Y1 = heave100_model1.predict(train_heave100_x1)

pretrain_surge50_Y1 = surge50_model1.predict(train_surge50_x1[300:,:])
# pretrain_surge100_Y1 = surge100_model1.predict(train_surge100_x1)

pretrain_pitch50_Y1 = pitch50_model1.predict(train_pitch50_x1)
# pretrain_pitch100_Y1 = pitch100_model1.predict(train_pitch100_x1)
print(pretrain_heave50_Y1.shape)
print(pretrain_surge50_Y1.shape)
print(pretrain_pitch50_Y1.shape)
# Out:
# (3000, 1)
# (3000, 1)
# (3000, 1)

# %%
pre_heave50_Y1 = heave50_model1.predict(valid_heave50_x1)
# pretrain_heave100_Y1 = heave100_model1.predict(train_heave100_x1)

pre_surge50_Y1 = surge50_model1.predict(valid_surge50_x1)
# pretrain_surge100_Y1 = surge100_model1.predict(train_surge100_x1)

pre_pitch50_Y1 = pitch50_model1.predict(valid_pitch50_x1)
# pretrain_pitch100_Y1 = pitch100_model1.predict(train_pitch100_x1)
print(pre_heave50_Y1.shape)
print(pre_surge50_Y1.shape)
print(pre_pitch50_Y1.shape)
# Out:
# (4500, 1)
# (4500, 1)
# (4500, 1)

# %%
# 输入500步长输出10步长Force1
force150_scaled1 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[3500:,:], 4, 509)
force150_x1,force150_y1 = split_sequence(force150_scaled1, 500)
# print(force150_x1.shape)
# 输入100步长输出1步长
# force1100_scaled1 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[300:,:], 4, 100)
# force1100_x1,force1100_y1 = split_sequence(force1100_scaled1, 100)
# print(force1100_x1.shape)

# %%
train_force150_x1, train_force150_y1, valid_force150_x1, valid_force150_y1 = split_train_valid(force150_x1,force150_y1, 4500, 7500, 12000)
train50_x_Force1, valid50_x_Force1 = np.hstack((pretrain_heave50_Y1, pretrain_surge50_Y1, pretrain_pitch50_Y1)), np.hstack((pre_heave50_Y1, pre_surge50_Y1, pre_pitch50_Y1))
train50_y_Force1, valid50_y_Force1 = train_force150_y1, valid_force150_y1

# %%
N_model50_Force1, N_history50_Force1, N_pre50_train_Y_Force1, N_pre50_Y_Force1 = Model_NN(train50_x_Force1, train50_y_Force1, valid50_x_Force1, valid50_y_Force1, lr=0.01, epochs=1000, batch_size=256)
# Out:
# Train on 3000 samples, validate on 4500 samples
# Epoch 1/1000
#  - 0s - loss: 0.0742 - val_loss: 0.0256
# Epoch 2/1000
#  - 0s - loss: 0.0135 - val_loss: 0.0207
# Epoch 3/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0212
# Epoch 4/1000
#  - 0s - loss: 0.0067 - val_loss: 0.0215
# Epoch 5/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0198
# Epoch 6/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0204
# Epoch 7/1000
#  - 0s - loss: 0.0064 - val_loss: 0.0208
# Epoch 8/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0207
# Epoch 9/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0205
# Epoch 10/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0205
# Epoch 11/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0205
# Epoch 12/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0205
# Epoch 13/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0205
# Epoch 14/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0205
# Epoch 15/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0205
# Epoch 16/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0204
# Epoch 17/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0204
# Epoch 18/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0204
# Epoch 19/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0204
# Epoch 20/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0204
# Epoch 21/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0204
# Epoch 22/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0204
# Epoch 23/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0204
# Epoch 24/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0204
# Epoch 25/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0205
# Epoch 26/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0205
# Epoch 27/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0205
# Epoch 28/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0205
# Epoch 29/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0205
# Epoch 30/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0205
# Epoch 31/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0205
# Epoch 32/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0205
# Epoch 33/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0206
# Epoch 34/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0206
# Epoch 35/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0206
# Epoch 36/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0206
# Epoch 37/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0207
# Epoch 38/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0207
# Epoch 39/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0207
# Epoch 40/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0207
# Epoch 41/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0208
# Epoch 42/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0208
# Epoch 43/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0208
# Epoch 44/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0209
# Epoch 45/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0209
# Epoch 46/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0209
# Epoch 47/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0209
# Epoch 48/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0209
# Epoch 49/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0208
# Epoch 50/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0207
# Epoch 51/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0206
# Epoch 52/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0204
# Epoch 53/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0202
# Epoch 54/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0200
# Epoch 55/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0201
# Epoch 56/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0203
# Epoch 57/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0201
# Epoch 58/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0206
# Epoch 59/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0216
# Epoch 60/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0218
# Epoch 61/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0215
# Epoch 62/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0213
# Epoch 63/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0211
# Epoch 64/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0211
# Epoch 65/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0210
# Epoch 66/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0209
# Epoch 67/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0206
# Epoch 68/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0204
# Epoch 69/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0202
# Epoch 70/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0202
# Epoch 71/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0203
# Epoch 72/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0204
# Epoch 73/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0208
# Epoch 74/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0214
# Epoch 75/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0217
# Epoch 76/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0218
# Epoch 77/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0217
# Epoch 78/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0214
# Epoch 79/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0212
# Epoch 80/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0209
# Epoch 81/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0206
# Epoch 82/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0204
# Epoch 83/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0204
# Epoch 84/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0204
# Epoch 85/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0206
# Epoch 86/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0209
# Epoch 87/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0212
# Epoch 88/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0214
# Epoch 89/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0215
# Epoch 90/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0214
# Epoch 91/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0212
# Epoch 92/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 93/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0208
# Epoch 94/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0207
# Epoch 95/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0206
# Epoch 96/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0207
# Epoch 97/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0208
# Epoch 98/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0210
# Epoch 99/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0211
# Epoch 100/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0212
# Epoch 101/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0212
# Epoch 102/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 103/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 104/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0209
# Epoch 105/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0209
# Epoch 106/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0209
# Epoch 107/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0209
# Epoch 108/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0209
# Epoch 109/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 110/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 111/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 112/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 113/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 114/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 115/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 116/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 117/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 118/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 119/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 120/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 121/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 122/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 123/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 124/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 125/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 126/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 127/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 128/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 129/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0210
# Epoch 130/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 131/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 132/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 133/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 134/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 135/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 136/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 137/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 138/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 139/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 140/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 141/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 142/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 143/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 144/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 145/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 146/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 147/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 148/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 149/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 150/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 151/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 152/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 153/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 154/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 155/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 156/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 157/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 158/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 159/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 160/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 161/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 162/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 163/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 164/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 165/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 166/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 167/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 168/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 169/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 170/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 171/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 172/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 173/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 174/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 175/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 176/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 177/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 178/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0211
# Epoch 179/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 180/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 181/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 182/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 183/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 184/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 185/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 186/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 187/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 188/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 189/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 190/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 191/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 192/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 193/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 194/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 195/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 196/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 197/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 198/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 199/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 200/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0211
# Epoch 201/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 202/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 203/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 204/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 205/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 206/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 207/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 208/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 209/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 210/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 211/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 212/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 213/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 214/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 215/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 216/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 217/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 218/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 219/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 220/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 221/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 222/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 223/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 224/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 225/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 226/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 227/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 228/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 229/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 230/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 231/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 232/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 233/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 234/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 235/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 236/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 237/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 238/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 239/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 240/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 241/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 242/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 243/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 244/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 245/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 246/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 247/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0210
# Epoch 248/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 249/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 250/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 251/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 252/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 253/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 254/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 255/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 256/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 257/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 258/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 259/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 260/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 261/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 262/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 263/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 264/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 265/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 266/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 267/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 268/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 269/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 270/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 271/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 272/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 273/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 274/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 275/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 276/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 277/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 278/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 279/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 280/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 281/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 282/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0209
# Epoch 283/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0209
# Epoch 284/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0209
# Epoch 285/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0209
# Epoch 286/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 287/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 288/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 289/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 290/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 291/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 292/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 293/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 294/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 295/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 296/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 297/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 298/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 299/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 300/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 301/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 302/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 303/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 304/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 305/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 306/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 307/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 308/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 309/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 310/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 311/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 312/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 313/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 314/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 315/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 316/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 317/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 318/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 319/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 320/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 321/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 322/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 323/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 324/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 325/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 326/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 327/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 328/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 329/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 330/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 331/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 332/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 333/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 334/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 335/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 336/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 337/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 338/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 339/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 340/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 341/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 342/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 343/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 344/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 345/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 346/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 347/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 348/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 349/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 350/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 351/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 352/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 353/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 354/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 355/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 356/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 357/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 358/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 359/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 360/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 361/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 362/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 363/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 364/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 365/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 366/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 367/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 368/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 369/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 370/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 371/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 372/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 373/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 374/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 375/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 376/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 377/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 378/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 379/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 380/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 381/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 382/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 383/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 384/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 385/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 386/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 387/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 388/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 389/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 390/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 391/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 392/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 393/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 394/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 395/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 396/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 397/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 398/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 399/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 400/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 401/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 402/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 403/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 404/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 405/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 406/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 407/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 408/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 409/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 410/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 411/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 412/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 413/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 414/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 415/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 416/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 417/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 418/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 419/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 420/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 421/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 422/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 423/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 424/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 425/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 426/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 427/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 428/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 429/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 430/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 431/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 432/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 433/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 434/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 435/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 436/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 437/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0208
# Epoch 438/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 439/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 440/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 441/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 442/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 443/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 444/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 445/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 446/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 447/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 448/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 449/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 450/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 451/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 452/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 453/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 454/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 455/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 456/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 457/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 458/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 459/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 460/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 461/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 462/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 463/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 464/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 465/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 466/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 467/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 468/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 469/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 470/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 471/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 472/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 473/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 474/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 475/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 476/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 477/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 478/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 479/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 480/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 481/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 482/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 483/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 484/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 485/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 486/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 487/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 488/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 489/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 490/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 491/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 492/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 493/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 494/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 495/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 496/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 497/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 498/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 499/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 500/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 501/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 502/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 503/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 504/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 505/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 506/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 507/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 508/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 509/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 510/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 511/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 512/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 513/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 514/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 515/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 516/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 517/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 518/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 519/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 520/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 521/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 522/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 523/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 524/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 525/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 526/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 527/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 528/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 529/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 530/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 531/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 532/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 533/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 534/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 535/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 536/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 537/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 538/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 539/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 540/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 541/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 542/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 543/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 544/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 545/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 546/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 547/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 548/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 549/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 550/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 551/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 552/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 553/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 554/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 555/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 556/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 557/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 558/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 559/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 560/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 561/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 562/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 563/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 564/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 565/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 566/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 567/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 568/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 569/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 570/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 571/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 572/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 573/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 574/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 575/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 576/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 577/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 578/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 579/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 580/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 581/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 582/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 583/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 584/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 585/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 586/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 587/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 588/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 589/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 590/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 591/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 592/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 593/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 594/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 595/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 596/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 597/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 598/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 599/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 600/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 601/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 602/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 603/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 604/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 605/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 606/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 607/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 608/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 609/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 610/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 611/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 612/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 613/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 614/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 615/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 616/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 617/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 618/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 619/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 620/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 621/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 622/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 623/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 624/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 625/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 626/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 627/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 628/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 629/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 630/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 631/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 632/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 633/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 634/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 635/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 636/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 637/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 638/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 639/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 640/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 641/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 642/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 643/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 644/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 645/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 646/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 647/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 648/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 649/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 650/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 651/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 652/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 653/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 654/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 655/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 656/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 657/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 658/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 659/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 660/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 661/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 662/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 663/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 664/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 665/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 666/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 667/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 668/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 669/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 670/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 671/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 672/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 673/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 674/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 675/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 676/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 677/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 678/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 679/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 680/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 681/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 682/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 683/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 684/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 685/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 686/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 687/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 688/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 689/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 690/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 691/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 692/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 693/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 694/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 695/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 696/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 697/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 698/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 699/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 700/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 701/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 702/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 703/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 704/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 705/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 706/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 707/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 708/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 709/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 710/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 711/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 712/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 713/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 714/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 715/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 716/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 717/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 718/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 719/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 720/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 721/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 722/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 723/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 724/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 725/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 726/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 727/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 728/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 729/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 730/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 731/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 732/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 733/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 734/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 735/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 736/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 737/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 738/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 739/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 740/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 741/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 742/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 743/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 744/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 745/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 746/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 747/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 748/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 749/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 750/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 751/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 752/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 753/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 754/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 755/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 756/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 757/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 758/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 759/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 760/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 761/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 762/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 763/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 764/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 765/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 766/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 767/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 768/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 769/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 770/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 771/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 772/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 773/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 774/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 775/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 776/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 777/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 778/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 779/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 780/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 781/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 782/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 783/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 784/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 785/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 786/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 787/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 788/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 789/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 790/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 791/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 792/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 793/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 794/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 795/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 796/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 797/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 798/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 799/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 800/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 801/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 802/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 803/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 804/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 805/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 806/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 807/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 808/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 809/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 810/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 811/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 812/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 813/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 814/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 815/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 816/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 817/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 818/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 819/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 820/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 821/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 822/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 823/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 824/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 825/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 826/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 827/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 828/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 829/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 830/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 831/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 832/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 833/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 834/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 835/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 836/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 837/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 838/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 839/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 840/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 841/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 842/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 843/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 844/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 845/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 846/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 847/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 848/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 849/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 850/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 851/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 852/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 853/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 854/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 855/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 856/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 857/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 858/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 859/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 860/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 861/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 862/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 863/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 864/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 865/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 866/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 867/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 868/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 869/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 870/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 871/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 872/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 873/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 874/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 875/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 876/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 877/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 878/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 879/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 880/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 881/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 882/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 883/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 884/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 885/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 886/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 887/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 888/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 889/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 890/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 891/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 892/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 893/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 894/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 895/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 896/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 897/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 898/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 899/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 900/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 901/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 902/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 903/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 904/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 905/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 906/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 907/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 908/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 909/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 910/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 911/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 912/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 913/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 914/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 915/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 916/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 917/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 918/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 919/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 920/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 921/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 922/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 923/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 924/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 925/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 926/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 927/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 928/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 929/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 930/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 931/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 932/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 933/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 934/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 935/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 936/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 937/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 938/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 939/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 940/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 941/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 942/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 943/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 944/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 945/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 946/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 947/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 948/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 949/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 950/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 951/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 952/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 953/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 954/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 955/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 956/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 957/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 958/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 959/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 960/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 961/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 962/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 963/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 964/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 965/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 966/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0208
# Epoch 967/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 968/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 969/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 970/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 971/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 972/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 973/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 974/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 975/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 976/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 977/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 978/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 979/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 980/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 981/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 982/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 983/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 984/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 985/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 986/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 987/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 988/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 989/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 990/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 991/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 992/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 993/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 994/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 995/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 996/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 997/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 998/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 999/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Epoch 1000/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0207
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 150)               600
# _________________________________________________________________
# dense_8 (Dense)              (None, 150)               22650
# _________________________________________________________________
# dense_9 (Dense)              (None, 150)               22650
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 46,051
# Trainable params: 46,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
fan_force150_real1,fan_force150_pre1 = FanGuiHua_force1(valid50_y_Force1,N_pre50_Y_Force1)

np.savetxt('force1500_步长10_混合注意力.csv',np.hstack((fan_force150_real1,fan_force150_pre1)),delimiter=',')

# %%
# 输入50步长输出1步长Force2
force250_scaled1 = deal_data2(np.hstack((Heave,Surge,Pitch,Force2))[3500:,:], 4, 509)
force250_x1,force250_y1 = split_sequence(force250_scaled1, 500)
# print(force150_x1.shape)
# 输入100步长输出1步长
# force1100_scaled1 = deal_data2(np.hstack((Heave,Surge,Pitch,Force1))[300:,:], 4, 100)
# force1100_x1,force1100_y1 = split_sequence(force1100_scaled1, 100)
# print(force1100_x1.shape)

# %%
train_force250_x1, train_force250_y1, valid_force250_x1, valid_force250_y1 = split_train_valid(force250_x1,force250_y1, 4500, 7500, 12000)
train50_x_Force2, valid50_x_Force2 = np.hstack((pretrain_heave50_Y1, pretrain_surge50_Y1, pretrain_pitch50_Y1)), np.hstack((pre_heave50_Y1, pre_surge50_Y1, pre_pitch50_Y1))
train50_y_Force2, valid50_y_Force2 = train_force250_y1, valid_force250_y1

# %%
N_model50_Force2, N_history50_Force2, N_pre50_train_Y_Force2, N_pre50_Y_Force2 = Model_NN(train50_x_Force2, train50_y_Force2, valid50_x_Force2, valid50_y_Force2, lr=0.01, epochs=1000, batch_size=256)
# Out:
# Train on 3000 samples, validate on 4500 samples
# Epoch 1/1000
#  - 0s - loss: 0.0237 - val_loss: 0.0206
# Epoch 2/1000
#  - 0s - loss: 0.0127 - val_loss: 0.0222
# Epoch 3/1000
#  - 0s - loss: 0.0127 - val_loss: 0.0183
# Epoch 4/1000
#  - 0s - loss: 0.0128 - val_loss: 0.0217
# Epoch 5/1000
#  - 0s - loss: 0.0134 - val_loss: 0.0215
# Epoch 6/1000
#  - 0s - loss: 0.0119 - val_loss: 0.0178
# Epoch 7/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0191
# Epoch 8/1000
#  - 0s - loss: 0.0110 - val_loss: 0.0200
# Epoch 9/1000
#  - 0s - loss: 0.0109 - val_loss: 0.0185
# Epoch 10/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0188
# Epoch 11/1000
#  - 0s - loss: 0.0107 - val_loss: 0.0193
# Epoch 12/1000
#  - 0s - loss: 0.0107 - val_loss: 0.0187
# Epoch 13/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0188
# Epoch 14/1000
#  - 0s - loss: 0.0105 - val_loss: 0.0190
# Epoch 15/1000
#  - 0s - loss: 0.0105 - val_loss: 0.0188
# Epoch 16/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0188
# Epoch 17/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0189
# Epoch 18/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0188
# Epoch 19/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0188
# Epoch 20/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0188
# Epoch 21/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0188
# Epoch 22/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0188
# Epoch 23/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0188
# Epoch 24/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0188
# Epoch 25/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0188
# Epoch 26/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0187
# Epoch 27/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0187
# Epoch 28/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0187
# Epoch 29/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0187
# Epoch 30/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0187
# Epoch 31/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0187
# Epoch 32/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0187
# Epoch 33/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0187
# Epoch 34/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0187
# Epoch 35/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0187
# Epoch 36/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0187
# Epoch 37/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0187
# Epoch 38/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0187
# Epoch 39/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0187
# Epoch 40/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0187
# Epoch 41/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0187
# Epoch 42/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0187
# Epoch 43/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0187
# Epoch 44/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0187
# Epoch 45/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 46/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 47/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 48/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 49/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 50/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 51/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 52/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 53/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 54/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 55/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 56/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 57/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 58/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 59/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 60/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 61/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 62/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 63/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 64/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 65/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 66/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 67/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 68/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 69/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 70/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 71/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 72/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0187
# Epoch 73/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 74/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 75/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 76/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 77/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 78/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 79/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 80/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 81/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 82/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 83/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 84/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 85/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 86/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 87/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 88/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 89/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 90/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 91/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 92/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 93/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 94/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 95/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 96/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 97/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 98/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 99/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 100/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0186
# Epoch 101/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 102/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 103/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 104/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 105/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 106/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 107/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 108/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 109/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 110/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 111/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 112/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 113/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 114/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 115/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0186
# Epoch 116/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 117/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0186
# Epoch 118/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 119/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0186
# Epoch 120/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 121/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 122/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 123/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 124/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 125/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 126/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 127/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 128/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 129/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 130/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 131/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 132/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 133/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 134/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 135/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 136/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 137/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 138/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 139/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 140/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 141/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 142/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 143/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 144/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 145/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 146/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 147/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 148/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 149/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 150/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 151/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 152/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 153/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 154/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 155/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 156/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 157/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 158/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 159/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 160/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 161/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 162/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 163/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 164/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 165/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 166/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 167/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 168/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 169/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 170/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 171/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 172/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 173/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 174/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 175/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 176/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 177/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 178/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 179/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 180/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 181/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 182/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 183/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 184/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 185/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 186/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 187/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 188/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 189/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 190/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 191/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 192/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 193/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 194/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 195/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 196/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 197/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 198/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 199/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 200/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 201/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 202/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 203/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 204/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 205/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 206/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 207/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 208/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 209/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 210/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 211/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 212/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 213/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 214/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 215/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 216/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 217/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 218/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 219/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 220/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 221/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 222/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 223/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 224/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 225/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 226/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 227/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 228/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 229/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 230/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 231/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 232/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 233/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 234/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 235/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 236/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 237/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 238/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 239/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 240/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 241/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 242/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 243/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 244/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 245/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 246/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 247/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 248/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 249/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 250/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 251/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 252/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 253/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 254/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 255/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 256/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 257/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 258/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 259/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 260/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 261/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 262/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 263/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0188
# Epoch 264/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 265/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 266/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 267/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 268/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 269/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 270/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 271/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 272/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 273/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 274/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 275/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 276/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 277/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 278/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 279/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 280/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 281/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 282/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 283/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 284/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 285/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 286/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 287/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 288/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 289/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 290/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 291/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 292/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 293/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 294/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 295/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 296/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 297/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 298/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 299/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 300/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 301/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 302/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 303/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 304/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 305/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 306/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 307/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 308/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 309/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 310/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 311/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 312/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 313/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 314/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 315/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 316/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 317/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 318/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 319/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 320/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 321/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 322/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 323/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 324/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 325/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 326/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 327/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 328/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 329/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 330/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 331/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 332/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 333/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 334/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 335/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 336/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 337/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 338/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 339/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 340/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 341/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 342/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 343/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 344/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 345/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 346/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 347/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 348/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 349/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 350/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 351/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 352/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 353/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 354/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 355/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 356/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 357/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 358/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 359/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 360/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 361/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 362/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0187
# Epoch 363/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 364/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0186
# Epoch 365/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0187
# Epoch 366/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0187
# Epoch 367/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 368/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 369/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 370/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 371/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 372/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 373/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 374/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 375/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 376/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 377/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 378/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 379/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 380/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 381/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 382/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 383/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 384/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 385/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 386/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 387/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 388/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 389/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 390/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 391/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 392/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 393/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 394/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 395/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 396/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 397/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 398/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 399/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 400/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 401/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 402/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 403/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 404/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0187
# Epoch 405/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 406/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0187
# Epoch 407/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 408/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0187
# Epoch 409/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 410/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0187
# Epoch 411/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 412/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 413/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 414/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 415/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 416/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 417/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 418/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 419/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 420/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 421/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 422/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 423/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 424/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 425/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 426/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 427/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 428/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 429/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 430/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0187
# Epoch 431/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 432/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 433/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 434/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 435/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 436/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 437/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 438/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 439/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 440/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 441/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 442/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 443/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 444/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 445/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 446/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 447/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 448/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 449/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 450/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 451/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 452/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 453/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 454/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 455/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 456/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 457/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 458/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 459/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 460/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 461/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 462/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 463/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 464/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0187
# Epoch 465/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 466/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0187
# Epoch 467/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 468/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 469/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0187
# Epoch 470/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 471/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0187
# Epoch 472/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 473/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 474/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 475/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 476/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 477/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 478/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 479/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 480/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 481/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 482/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 483/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 484/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 485/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 486/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 487/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 488/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 489/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 490/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 491/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 492/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 493/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 494/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 495/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 496/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 497/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 498/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 499/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 500/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0187
# Epoch 501/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 502/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0187
# Epoch 503/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 504/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0187
# Epoch 505/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 506/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 507/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 508/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 509/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 510/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 511/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 512/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 513/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 514/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 515/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 516/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 517/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 518/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 519/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 520/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 521/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 522/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 523/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 524/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 525/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 526/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 527/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 528/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 529/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 530/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 531/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 532/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 533/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 534/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 535/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 536/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 537/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 538/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 539/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 540/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 541/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 542/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 543/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0187
# Epoch 544/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 545/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0187
# Epoch 546/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0186
# Epoch 547/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 548/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 549/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 550/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 551/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 552/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 553/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 554/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 555/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 556/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 557/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 558/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 559/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 560/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 561/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 562/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 563/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 564/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 565/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 566/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 567/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 568/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 569/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 570/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 571/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 572/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 573/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 574/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 575/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 576/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 577/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 578/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 579/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0186
# Epoch 580/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 581/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 582/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 583/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 584/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 585/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 586/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 587/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 588/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 589/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 590/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 591/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 592/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 593/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0188
# Epoch 594/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 595/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 596/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 597/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0187
# Epoch 598/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0187
# Epoch 599/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0187
# Epoch 600/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0186
# Epoch 601/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0186
# Epoch 602/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0186
# Epoch 603/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0185
# Epoch 604/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0185
# Epoch 605/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0185
# Epoch 606/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0184
# Epoch 607/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0184
# Epoch 608/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0184
# Epoch 609/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0183
# Epoch 610/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0183
# Epoch 611/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0183
# Epoch 612/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0182
# Epoch 613/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0182
# Epoch 614/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0182
# Epoch 615/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0182
# Epoch 616/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0182
# Epoch 617/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0182
# Epoch 618/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0181
# Epoch 619/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0181
# Epoch 620/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0181
# Epoch 621/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0181
# Epoch 622/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0181
# Epoch 623/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0181
# Epoch 624/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0181
# Epoch 625/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0181
# Epoch 626/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 627/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 628/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 629/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 630/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 631/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 632/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 633/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 634/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 635/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 636/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 637/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 638/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 639/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 640/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 641/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0180
# Epoch 642/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0179
# Epoch 643/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0179
# Epoch 644/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0179
# Epoch 645/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0179
# Epoch 646/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0179
# Epoch 647/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0179
# Epoch 648/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0179
# Epoch 649/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0179
# Epoch 650/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0179
# Epoch 651/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0179
# Epoch 652/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 653/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 654/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 655/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 656/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 657/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 658/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 659/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 660/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 661/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 662/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 663/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 664/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 665/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 666/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 667/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 668/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 669/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 670/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 671/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 672/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 673/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0179
# Epoch 674/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 675/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 676/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 677/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 678/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 679/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 680/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 681/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 682/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 683/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 684/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 685/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 686/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 687/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 688/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 689/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 690/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 691/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 692/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 693/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 694/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 695/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 696/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 697/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 698/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 699/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 700/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 701/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 702/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 703/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 704/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 705/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 706/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 707/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 708/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 709/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 710/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 711/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 712/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 713/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 714/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 715/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 716/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 717/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 718/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 719/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 720/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 721/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 722/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 723/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 724/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 725/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 726/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 727/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 728/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 729/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 730/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 731/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 732/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 733/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 734/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 735/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 736/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 737/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 738/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 739/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 740/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 741/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 742/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 743/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 744/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 745/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 746/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 747/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 748/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0178
# Epoch 749/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 750/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 751/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 752/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 753/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 754/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 755/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 756/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 757/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 758/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 759/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 760/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 761/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 762/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 763/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 764/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 765/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 766/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 767/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 768/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 769/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 770/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 771/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 772/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 773/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 774/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 775/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 776/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 777/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 778/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 779/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 780/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 781/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 782/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 783/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 784/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 785/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 786/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 787/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 788/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 789/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 790/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 791/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 792/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 793/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 794/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 795/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 796/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 797/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 798/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 799/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 800/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 801/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 802/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 803/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 804/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 805/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 806/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 807/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 808/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 809/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 810/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 811/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 812/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 813/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 814/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 815/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 816/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 817/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 818/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 819/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 820/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 821/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 822/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 823/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 824/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 825/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 826/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 827/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 828/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 829/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 830/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 831/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 832/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 833/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 834/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 835/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 836/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 837/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 838/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 839/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 840/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 841/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 842/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 843/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 844/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 845/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 846/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 847/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 848/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 849/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 850/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 851/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 852/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0177
# Epoch 853/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 854/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 855/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 856/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 857/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 858/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 859/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 860/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 861/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 862/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 863/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 864/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 865/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 866/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 867/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 868/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 869/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 870/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 871/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 872/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 873/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 874/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 875/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 876/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 877/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 878/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 879/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 880/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 881/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 882/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 883/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 884/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 885/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 886/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 887/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 888/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 889/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 890/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 891/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 892/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 893/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 894/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 895/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 896/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 897/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 898/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 899/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0177
# Epoch 900/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 901/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 902/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 903/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 904/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 905/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 906/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 907/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 908/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 909/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 910/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 911/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 912/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 913/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 914/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 915/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 916/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 917/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 918/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 919/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 920/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 921/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 922/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 923/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 924/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 925/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 926/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 927/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 928/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 929/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 930/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 931/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 932/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 933/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 934/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 935/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 936/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 937/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 938/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 939/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 940/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 941/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 942/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 943/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 944/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 945/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 946/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 947/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 948/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 949/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0176
# Epoch 950/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0176
# Epoch 951/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0176
# Epoch 952/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0176
# Epoch 953/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0176
# Epoch 954/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0176
# Epoch 955/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0176
# Epoch 956/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0176
# Epoch 957/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0176
# Epoch 958/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0176
# Epoch 959/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0175
# Epoch 960/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0175
# Epoch 961/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0175
# Epoch 962/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0175
# Epoch 963/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0175
# Epoch 964/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0175
# Epoch 965/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0174
# Epoch 966/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0174
# Epoch 967/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0174
# Epoch 968/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0173
# Epoch 969/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0173
# Epoch 970/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0173
# Epoch 971/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0173
# Epoch 972/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0173
# Epoch 973/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0172
# Epoch 974/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0171
# Epoch 975/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0171
# Epoch 976/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0170
# Epoch 977/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0170
# Epoch 978/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0169
# Epoch 979/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0168
# Epoch 980/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0168
# Epoch 981/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0168
# Epoch 982/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0167
# Epoch 983/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0167
# Epoch 984/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0168
# Epoch 985/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0168
# Epoch 986/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0169
# Epoch 987/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0168
# Epoch 988/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0165
# Epoch 989/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0165
# Epoch 990/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0166
# Epoch 991/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0166
# Epoch 992/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0165
# Epoch 993/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0165
# Epoch 994/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0165
# Epoch 995/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0165
# Epoch 996/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0165
# Epoch 997/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0165
# Epoch 998/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0165
# Epoch 999/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0165
# Epoch 1000/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0165
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 150)               600
# _________________________________________________________________
# dense_20 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_21 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 46,051
# Trainable params: 46,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
fan_force250_real1,fan_force250_pre1 = FanGuiHua_force2(valid50_y_Force2,N_pre50_Y_Force2)

np.savetxt('force2500_步长10_混合注意力.csv',np.hstack((fan_force250_real1,fan_force250_pre1)),delimiter=',')

# %%
RNSE(valid50_y_Force1,N_pre50_Y_Force1)
Acc(valid50_y_Force1,N_pre50_Y_Force1)
# Out:
# RMSE(sklearn): 0.14384605091768712
# Acc: 0.9799253869501406

# %%
RNSE(valid50_y_Force2,N_pre50_Y_Force2)
Acc(valid50_y_Force2,N_pre50_Y_Force2)
# Out:
# RMSE(sklearn): 0.12833857624441314
# Acc: 0.8404282555169895
